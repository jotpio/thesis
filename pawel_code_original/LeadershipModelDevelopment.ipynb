# %%
# %matplotlib notebook
#%matplotlib widget
#%pylab inline
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from pylab import *
import numpy as np
import sys
sys.path.append("/home/prom/Dropbox/work/AG_Romanczuk/2017_Couzin_Leadership_Lilian/python/")
import ProcessTracks as pt
# %load_ext autoreload
# %autoreload 2
import SwarmLeadershipCouzin as slc
import pickle as pkl
import pandas as pd
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#fish parameter

N=3;              # default parameter 300
L=1000                # default parameter 50
L=88
time=300.0          # default parameter 300
dt=0.05             # default parameter 0.05



noisep=5;         # default parameter 0.2
BC=0; IC=0         # periodic boundary, random orientation, local random position x in [0,10], y in [0,10]
BC=1; IC=1         # reflecting boundary, random orientation, local random position x in [0,10], y in [0,10]
#BC=1; IC=1         # reflecting boundary, orientation biased to diagonal, local random position x in [0,10], y in [0,10]

repstrength=5.0     # default parameter 5.0
algstrength=0.0     # default parameter 1.0
attstrength=2.0     # default parameter 0.5

attstrengthDist=0   # attraction strenth distribution flag (0 - fixed/same for all, 1 - random)

reprange=3.0        # default parameter 1.0
algrange=10.0        # default parameter 5.0
attrange=20.0       # default parameter 25.0

speed0=6.0;         # speed0

leaderCount=1       # number of leads
################ Set multiple leaders ##############################
#leader_desiredPhi=[0.0,0.5*np.pi]
#leadershipRangeList=[18,22]
#leadershipRangeList=[10,12]

leadershipRange=12 #-1 #12

if(leaderCount>1):
    leadershipRangeList=[leadershipRange,50]
    leader_desiredPhi=[None,0.0]
else:
    leadershipRangeList=[leadershipRange]
    leader_desiredPhi=[0.0]
    
recruitingRange=8
recruitingAttStrength=10
recruitingTime=dt
recruitingSpeed=1.0*speed0
targetType=2  # target type: 0 - targetDist along x, 1 - diagonal, 2 - set to a certain position as in exp

targetVectorList=[[80,80]]
leader_repstrength=repstrength
leader_algstrength=8.0                  #algstrength defines the alignment with the target vector (not other fish!)
leader_attstrength=2.*attstrength 
leader_attstrength=10.0

leader_reprange=reprange
leader_algrange=5.0 
leader_attrange=100.0

leader_noisep=5.0
#leadingDistance=127.27
leadingDistance=500
int_type='matrix'
output=0.1

#dist_dependence='overlap'
dist_dependence='zone'

# initialize system parameters
params=slc.InitParams(N=N,L=L,time=time,dt=dt,BC=BC,IC=IC,output=output,int_type=int_type,                               
                        repstrength=repstrength,reprange=reprange,leadingDistance=leadingDistance,
                        algstrength=algstrength,algrange=algrange,
                        attstrength=attstrength,attrange=attrange,speed0=speed0,
                        attstrengthDist=attstrengthDist,
                        noisep=noisep,leaderCount=leaderCount,
                        targetType=targetType,targetVectorList=targetVectorList,
                        leader_noisep=leader_noisep,leader_attstrength=leader_attstrength,leader_algstrength=leader_algstrength,leader_repstrength=leader_repstrength,
                        leader_reprange=leader_reprange,leader_algrange=leader_algrange,leader_attrange=leader_attrange,
                        leadershipRange=leadershipRange,
                        recruitingAttStrength=recruitingAttStrength,
                        recruitingRange=recruitingRange,
                        recruitingTime=recruitingTime,
                        recruitingSpeed=recruitingSpeed,
                        leader_desiredPhi=leader_desiredPhi,
                        leadershipRangeList=leadershipRangeList)

#########################################
agentData=slc.AgentData(params)
slc.InitAgents(agentData,params)
##########################################
if(leaderCount>0):
        
        agentData.repstrength[:leaderCount]=leader_repstrength
        agentData.algstrength[:leaderCount]=leader_algstrength
        agentData.attstrength[:leaderCount]=leader_attstrength

        agentData.reprange[:leaderCount]=leader_reprange
        agentData.algrange[:leaderCount]=leader_algrange
        agentData.attrange[:leaderCount]=leader_attrange
        agentData.sigmap[:leaderCount]=np.sqrt(2.*dt*params['leader_noisep'])

print("N =",params['N'])
print("L =",params['L'])
print("leaderCount =",params['leaderCount'])
print("leadRange =",params['leadershipRange'])
print("recruitRange =",params['recruitingRange'])
print("attstrength =",params['attstrength'])
print("time =",params['time'])
print("noisep =",params['noisep'])
print("lead_noisep =",params['leader_noisep'])
print("lead_desPhi =",params['leader_desiredPhi'])
print("----------------------")
#print(agentData.algstrength)
print("agentData.sigmap     =",agentData.sigmap)
print("agentData.desiredPhi =",agentData.desiredPhi)
print("agentData.leadershipWeight  =",agentData.leadershipWeight)
print("agentData.leadershipRange  =",agentData.leadershipRange)
print("agentData.leadingTime       =",agentData.leadingTime)
print("agentData.pos=\n",agentData.pos)
print("agentData.initpos=\n",agentData.initpos)
print("agentData.targetVector=\n",agentData.targetVector)

#print(agentData.attstrength)
# Out:
# recruiting speed=6.0
# N = 3
# L = 88
# leaderCount = 1
# leadRange = 12
# recruitRange = 8
# attstrength = 2.0
# time = 300.0
# noisep = 5
# lead_noisep = 5.0
# lead_desPhi = [0.0]
# ----------------------
# agentData.sigmap     = [0.70710678 0.70710678 0.70710678]
# agentData.desiredPhi = [0.]
# agentData.leadershipWeight  = [1.]
# agentData.leadershipRange  = [12.]
# agentData.leadingTime       = [-1.]
# agentData.pos=
#  [[8.4461502  6.28641939]
#  [0.5294946  0.49975509]
#  [2.56173391 3.37630249]]
# agentData.initpos=
#  [[0. 0.]
#  [0. 0.]
#  [0. 0.]]
# agentData.targetVector=
#  [[80. 80.]
#  [nan nan]
#  [nan nan]]

# %%
agentData.leadershipRange
# Out:
# array([12.])

# %%
#params

# %%
#pkl.load(open('/home/prom/Seafile/Leadership/dataPrevious/speed5/para_leadershipRange_0_72_noisep_2.0_5.0.pkl','rb'))

# %%
tidx=-1
#print(outdata['POS'][tidx])
print(np.linalg.norm(np.diff(outdata['POS'][tidx],axis=0)))
#agentData.attrange
print("repstrengths",agentData.repstrength)
print("algstrengths",agentData.algstrength)
print("attstrengths",agentData.attstrength)
print("attrange",agentData.attrange)
print("algrange",agentData.algrange)
print(agentData.leadershipRange)
print(agentData.force_att)
# Out:
# 3.044703357735774
# repstrengths [0. 5.]
# algstrengths [3. 0.]
# attstrengths [0. 3.]
# attrange [ 0. 20.]
# algrange [ 0. 10.]
# [12.]
# [[0.         0.        ]
#  [0.48428216 0.87491188]]

# %%
#Single Run with leader

slc.InitAgents(agentData,params)
print(agentData.pos[:leaderCount])
#print(agentData.desiredPhi[:leaderCount])
outdata=slc.SingleRun(params,agentData);
print('finalStep   ={}'.format(outdata['finalStep']))
print('finalOutStep={}'.format(outdata['finalOutStep']))
print("-------------------")
#print(agentData.pos)
#print(agentData.POS)
#print(agentData.initpos)
###########################################################
# Plot Leading Ratio versus time
if(leaderCount>0):
    figure()
    
    leadingRecord=outdata['leadingRecord'][:,:].T
    timearray=np.arange(len(leadingRecord))*params['dt']
    plot(timearray,leadingRecord[:,0],label='0')
    if(leaderCount>1):
        plot(timearray,leadingRecord[:,1],label='1')
    legend()
    ylim([-0.05,1.05])
    xlabel("simulation time")
    ylabel("leading variable")
    leading_ratio0=np.sum(outdata['leadingRecord'][0])/len(outdata['leadingRecord'][0])
    print("LeadingRatio0={}".format(leading_ratio0))
    if(len(leadingRecord[1])>1):
        leading_ratio1=np.sum(outdata['leadingRecord'][1])/len(outdata['leadingRecord'][1])
        print("LeadingRatio1={}".format(leading_ratio1))
        
###########################################################

params['L']
POS=np.array(outdata['POS'])
circlepoints=20
radius=5
c=params['targetVectorList'][0]
theta=np.linspace(0,2*np.pi,circlepoints)
f=figure()
subplot(aspect='equal')
plot(POS[:,0,0],POS[:,0,1],'k',label='0')
plot(POS[:,1,0],POS[:,1,1],'r',label='1')
plot(POS[:,2,0],POS[:,2,1],'r--',label='1')
legend()
tight_layout()
if(targetType==2):
    plot(c[0]+radius*np.cos(theta),c[1]+radius*np.sin(theta),"m-")
    plot(c[0],c[1],'mo')
# Calculate total displacement along X as measure of leadership success
total_displacements_in_X=POS[-1,:,0]-POS[0,:,0]
#print(total_displacements_in_X)
avg_total_displacement=np.mean(total_displacements_in_X)
print("Avg. Total Displacement={}".format(avg_total_displacement))
#if(targetType==2):
#    xlim([0,L])
#    ylim([0,L])
xlabel("position x")
ylabel("position y")
print("Init. x-POS  : {}".format(POS[0,:,0]))
print("Final x-POS  : {}".format(POS[-1,:,0]))
print("Final delta x: {}".format(total_displacements_in_X))
print("Target vector:{}".format(params['targetVector']))
print("Final distance vector target x: {}".format(params['targetVector']-POS[-1,:]))
print("Final distance vector target x: {}".format(np.linalg.norm(params['targetVector']-POS[-1,:],axis=1)))
# Out:
# [[0.9688674 1.9722861]]
# Performing a single run.
# Target reached!
# i=0,s=1357
# agentData.POS[0]=[80.79295095 75.34150446]
# agentData.initpos[0]=[0.9688674 1.9722861]
# agentData.distTarget[0]=4.857499848383387
# agentData.leadingTime[0]=67.85000000000001
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leading agents. Stopping Simulation.
# [67.85]
# Stopping time: 67.85000000000001
# finalStep=1357, finalPosLeader=[[80.24524482 75.36262964]]
# Done!
# finalStep   =1357
# finalOutStep=678
# -------------------
# <img src="data:image/png;base64,..." width="697.5833333333334">
# LeadingRatio0=0.46720707442888726
# <img src="data:image/png;base64,..." width="697.5833333333334">
# Avg. Total Displacement=75.31885711241422
# Init. x-POS  : [0.9688674  7.96377227 6.38846495]
# Final x-POS  : [80.54465537 78.53216881 82.20085178]
# Final delta x: [79.57578797 70.56839654 75.81238683]
# Target vector:[80, 80]
# Final distance vector target x: [[-0.54465537  4.82686806]
#  [ 1.46783119  1.8944278 ]
#  [-2.20085178  1.21431611]]
# Final distance vector target x: [4.85749985 2.39653606 2.51362531]

# %%
outdata=slc.CalcLeadingPerformance(outdata,params)
print('targetMovement0',outdata['targetMovement0'])
print('leadingTime={}'.format(outdata['leadingTime']))
print('all_avgdist={}'.format(outdata['all_avgdist']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-b387e8dcd1ff> in <module>
# ----> 1 outdata=slc.CalcLeadingPerformance(outdata,params)
#       2 print('targetMovement0',outdata['targetMovement0'])
#       3 print('leadingTime={}'.format(outdata['leadingTime']))
#       4 print('all_avgdist={}'.format(outdata['all_avgdist']))
#
# ~/Dropbox/work/Projects/inProgress/RobofishLeadership/code/SwarmLeadershipCouzin.py in CalcLeadingPerformance(outdata, params, ignore_timepoints, verbose)
#    1048     targetVectorList=params['targetVectorList']
#    1049     for i in range(len(targetVectorList)):
# -> 1050         outdata['targetMovement{}'.format(i)]=CalcMovementSuccess(outdata['POS'],params,targetVectorList[i])
#    1051
#    1052     if(verbose):
#
# ~/Dropbox/work/Projects/inProgress/RobofishLeadership/code/SwarmLeadershipCouzin.py in CalcMovementSuccess(pos, params, targetVector)
#    1162 def CalcMovementSuccess(pos,params,targetVector):
#    1163     initTargetVec    =targetVector-pos[0]
# -> 1164     initTargetUnitVec=initTargetVec/np.linalg.norm(initTargetVec,axis=1)
#    1165     #print(initTargetUnitVec)
#    1166     displacementVector=pos[-1]-pos[0]
#
# ValueError: operands could not be broadcast together with shapes (3,2) (3,)

# %%
def DistToTarget(X,Y,targetPos=[80,80]):
    
    distX=X-targetPos[0]
    distY=Y-targetPos[1]
    dist =np.sqrt(distX**2+distY**2)
    
    return distX,distY,dist

def CalculateDistanceFromEndZone(X,Y,endzone=[[65,80],[65,80]]): 
    ''' Calculate Distance From Endzone.

        Parameters: 
        ----------
        X : x-coordinates (array like)
        Y : y-coordinates (array like)
        endzone : endzone coordinates ([[xmin,xmax],[ymin,ymax]])

        Returns:
        --------

        distX,distY: numpy arrays

    '''
    distX = np.zeros(np.shape(X))
    distY = np.zeros(np.shape(Y))
    xzone = endzone[0][0]
    yzone = endzone[1][0]
    distX[X<xzone]=xzone-X[X<xzone]
    distY[Y<yzone]=yzone-Y[Y<yzone]

    return distX,distY

def TransformResultsToRoboDF(outdata,params):
    
    number_of_fish=params['N']-1
    
    new_columns=['Framenumber','Behaviour',
                    'Robo Position x','Robo Position y',
                    'Robo Dist EndZone x','Robo Dist EndZone y',
                    'Robo Dist EndZone','Robo Speed EndZone',
                    'Robo VX','Robo VY','Robo Speed'
                    ]   
    
    for i in range(number_of_fish):
        idxstring=""
        if(i>0):
        
            idxstring=".%d" % i

            new_columns+=['Fish Position x'+idxstring,
                      'Fish Position y'+idxstring,  
                      'Fish Dist EndZone x'+idxstring,
                      'Fish Dist EndZone y'+idxstring,
                      'Fish Dist EndZone'+idxstring,
                      'Fish Speed EndZone'+idxstring,
                      'DeltaPosX'+idxstring,
                      'DeltaPosY'+idxstring,
                      'DeltaPos'+idxstring,
                      'Fish VX'+idxstring,
                      'Fish VY'+idxstring,
                      'DeltaVX'+idxstring,
                      'DeltaVY'+idxstring,
                      'Vrel'+idxstring
                     ]
    #print(new_columns)    
        
    POS=np.array(outdata['POS'])   
    dt=params['output']
    df_new=pd.DataFrame(columns=new_columns)
    X=POS[:,0,0]
    Y=POS[:,0,1]
    framenumber=np.arange(len(X))
    outstep=int(params['output']/params['dt'])
    
    distX,distY=CalculateDistanceFromEndZone(X,Y)
    df_new['Framenumber']=framenumber
    df_new['Behaviour']   =outdata['leadingRecord'][0][::outstep]
    df_new['Robo Position x']     = X
    df_new['Robo Position y']     = Y
    df_new['Robo Dist EndZone x'] = pd.Series(distX)
    df_new['Robo Dist EndZone y'] = pd.Series(distY)
    df_new['Robo Dist EndZone']   = np.sqrt(df_new['Robo Dist EndZone x']**2+df_new['Robo Dist EndZone y']**2)
    df_new['Robo Speed EndZone']  = -np.gradient(df_new['Robo Dist EndZone'])/dt
    VX=np.gradient(X)/dt
    VY=np.gradient(Y)/dt
    df_new['Robo VX']   = VX 
    df_new['Robo VY']   = VY
    df_new['Robo Speed']= np.sqrt(VX**2+VY**2)
    
    for i in range(number_of_fish):
        idxstring=""
        if(i>0):
            idxstring=".%d" % i

        #print("idxstring="+idxstring)

    
        X=POS[:,i+1,0]
        Y=POS[:,i+1,1]
        distX,distY=CalculateDistanceFromEndZone(X,Y)
        
        df_new['Fish Position x'+idxstring] = X
        df_new['Fish Position y'+idxstring] = Y
        VX=np.gradient(X)/dt
        VY=np.gradient(Y)/dt
        df_new['Fish VX'+idxstring]   = VX 
        df_new['Fish VY'+idxstring]   = VY
        df_new['Fish Speed'+idxstring]   = np.sqrt(df_new['Fish VX'+idxstring]**2+df_new['Fish VY'+idxstring]**2)
        df_new['Fish Dist EndZone x'+idxstring] = pd.Series(distX)
        df_new['Fish Dist EndZone y'+idxstring] = pd.Series(distY)
        df_new[ 'Fish Dist EndZone'+idxstring]  = np.sqrt(df_new['Fish Dist EndZone x'+idxstring]**2+df_new['Fish Dist EndZone y'+idxstring]**2)
        df_new['Fish Speed EndZone'+idxstring]  = -np.gradient(df_new['Fish Dist EndZone'+idxstring])/dt
        
        df_new['DeltaPosX'+idxstring]    = df_new['Robo Position x']-df_new['Fish Position x'+idxstring]
        df_new['DeltaPosY'+idxstring]    = df_new['Robo Position y']-df_new['Fish Position y'+idxstring]
        df_new[ 'DeltaPos'+idxstring]    = np.sqrt(df_new['DeltaPosX'+idxstring]**2 +  df_new['DeltaPosY'+idxstring]**2)
                   
#
        df_new.loc[:,'DeltaVX'+idxstring]  = df_new['Robo VX']-df_new['Fish VX'+idxstring]
        df_new.loc[:,'DeltaVY'+idxstring]  = df_new['Robo VY']-df_new['Fish VY'+idxstring]
        df_new.loc[:,'Vrel'+idxstring]     = df_new['DeltaVX'+idxstring]*df_new['DeltaPosX'+idxstring]+df_new['DeltaVY'+idxstring]*df_new['DeltaPosY'+idxstring]
        

    
    #print(dt)
    #print(df_new)
    return df_new

# %%
startmilling=np.where(df_new['Behaviour']=='Start (milling)')[0]
print(startmilling)
# Out:
# []

# %%
len(outdata['leadingRecord'][0][::outstep])
# Out:
# 581

# %%
params['output']
# Out:
# 0.1

# %%
df=TransformResultsToRoboDF(outdata,params)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-254-828ff32432f6> in <module>
# ----> 1 df=TransformResultsToRoboDF(outdata,params)
#
# <ipython-input-253-19250f8029c1> in TransformResultsToRoboDF(outdata, params)
#      75     distX,distY=CalculateDistanceFromEndZone(X,Y)
#      76     df_new['Framenumber']=framenumber
# ---> 77     df_new['Behaviour']   =outdata['leadingRecord'][0][::outstep]
#      78     df_new['Robo Position x']     = X
#      79     df_new['Robo Position y']     = Y
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3118         """
#    3119         self._ensure_valid_index(value)
# -> 3120         value = self._sanitize_column(key, value)
#    3121         NDFrame._set_item(self, key, value)
#    3122
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3766
#    3767             # turn me into an ndarray
# -> 3768             value = sanitize_index(value, self.index)
#    3769             if not isinstance(value, (np.ndarray, Index)):
#    3770                 if isinstance(value, list) and len(value) > 0:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/construction.py in sanitize_index(data, index)
#     745     """
#     746     if len(data) != len(index):
# --> 747         raise ValueError(
#     748             "Length of values "
#     749             f"({len(data)}) "
#
# ValueError: Length of values (117) does not match length of index (581)

# %%
df.DeltaPos
# Out:
# 0      4.962929
# 1      5.414980
# 2      5.728853
# 3      5.817912
# 4      5.869526
#          ...
# 576    2.627982
# 577    2.561969
# 578    2.544522
# 579    2.512223
# 580    2.350052
# Name: DeltaPos, Length: 581, dtype: float64

# %%
pt.CalcAverageVariables(df,fps=10,number_of_fish=1)
# Out:
# number of fish=1
# [0]
# -1
# Frame Start=1.0
# Frame at EndZone       (Robo,Fish)=(258.0,260.0)
# DeltaFrames to EndZone (Robo,Fish)=(257.0,259.0)
#    Trial  Robo Time To EndZone  Fish Time To EndZone  Avg. Dist  \
# 0  trial                  25.7                  25.9   4.798285
#
#    Robo Avg. Speed  Robo Avg. Speed EndZone  Robo LeadTime  Robo FollowTime  \
# 0            5.965                    0.171            0.0             57.9
#
#    Robo LeadRatio  Fish_Avg_Speed  Fish_Avg_Speed_EndZone
# 0             0.0           5.961                    0.22

# %%
alldat=pkl.load(open("/home/prom/work/Leadership/DATA/alldat_targetType2_Nl2_S6.0_leadershipRangeList_0.0_16.0_leader_algstrength_4.0_16.0.pkl",'rb'))
allpar=pkl.load(open("/home/prom/work/Leadership/DATA/para_targetType2_Nl2_S6.0_leadershipRangeList_0.0_16.0_leader_algstrength_4.0_16.0.pkl","rb"))

# %%
idx=1
allpar[idx]['leadershipRangeList']
params=allpar[idx]
outdat=alldat[idx]

# %%
params['output']/params['dt']
# Out:
# 10.0

# %%
df
# Out:
#      Framenumber  Behaviour  Robo Position x  Robo Position y  \
# 0              0        0.0         4.917484         7.023082
# 1              1        0.0         2.740475        11.290186
# 2              2        0.0        -0.109504        15.352962
# 3              3        0.0         0.031020        20.311973
# 4              4        0.0        -0.364433        25.277044
# ..           ...        ...              ...              ...
# 295          295        0.0        85.568329        67.773383
# 296          296        0.0        85.442396        72.768286
# 297          297        0.0        85.228440        77.761249
# 298          298        0.0        82.483182        81.746492
# 299          299        0.0        77.946932        83.818144
#
#      Robo Dist EndZone x  Robo Dist EndZone y  Robo Dist EndZone  \
# 0              60.082516            57.976918          83.493903
# 1              62.259525            53.709814          82.225255
# 2              65.109504            49.647038          81.878422
# 3              64.968980            44.688027          78.854220
# 4              65.364433            39.722956          76.488053
# ..                   ...                  ...                ...
# 295             0.000000             0.000000           0.000000
# 296             0.000000             0.000000           0.000000
# 297             0.000000             0.000000           0.000000
# 298             0.000000             0.000000           0.000000
# 299             0.000000             0.000000           0.000000
#
#      Robo Speed EndZone   Robo VX   Robo VY  ...  Fish Dist EndZone x  \
# 0              2.537296 -4.354018  8.534209  ...            56.326184
# 1              1.615481 -5.026988  8.329880  ...            58.613657
# 2              3.371035 -2.709455  9.021787  ...            60.837472
# 3              5.390368 -0.254929  9.924082  ...            63.175061
# 4              4.433624 -0.836348  9.930523  ...            65.176707
# ..                  ...       ...       ...  ...                  ...
# 295            2.204850  0.148598  9.973136  ...             0.000000
# 296           -0.000000 -0.339889  9.987866  ...             0.000000
# 297           -0.000000 -2.959214  8.978206  ...             0.000000
# 298           -0.000000 -7.281508  6.056895  ...             0.000000
# 299           -0.000000 -9.072498  4.143304  ...             0.000000
#
#      Fish Dist EndZone y  Fish Dist EndZone  Fish Speed EndZone  DeltaPosX  \
# 0              58.455229          81.176676           -0.509262  -3.756333
# 1              56.528727          81.431307           -0.531323  -3.645868
# 2              54.543553          81.708000           -0.830589  -4.272032
# 3              52.687107          82.261896           -0.786024  -1.793919
# 4              50.569368          82.494024            1.474967  -0.187726
# ..                   ...                ...                 ...        ...
# 295             0.506474           0.506474            3.493827   0.782595
# 296             0.000000           0.000000            0.506474   0.678691
# 297             0.000000           0.000000           -0.000000   1.802819
# 298             0.000000           0.000000           -0.000000   0.921806
# 299             0.000000           0.000000           -0.000000  -2.800596
#
#      DeltaPosY   DeltaPos   DeltaVX   DeltaVY       Vrel
# 0     0.478311   3.786663  0.220929  4.681205   1.409186
# 1     2.818913   4.608538 -0.515699  4.418204  14.334707
# 2     4.896515   6.498163  1.851949  5.180167  17.453181
# 3     7.999080   8.197770  4.084306  5.949896  40.266786
# 4    10.846411  10.848036  1.280720  4.819312  52.031816
# ..         ...        ...       ...       ...        ...
# 295   3.279857   3.371931  0.332380  3.992780  13.355868
# 296   5.281757   5.325184  1.020224  4.348186  23.658479
# 297   7.628043   7.838188  0.243115  3.995327  30.914821
# 298   9.277084   9.322769 -4.603415  0.938383   4.462004
# 299   8.566426   9.012602 -7.444804 -1.421316   8.674290
#
# [300 rows x 26 columns]

# %%
len(outdata['POS'])
POS=np.array(outdat['POS'])
plot(POS[:,0,0],POS[:,0,1],'-')
plot(POS[:,1,0],POS[:,1,1],'-')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
df=TransformResultsToRoboDF(outdat,params)

# %%
pt.CalcAverageVariables(df,fps=10,number_of_fish=1)
# Out:
# number of fish=1
# [0]
# -1
# Frame Start=1.0
# Frame at EndZone       (Robo,Fish)=(258.0,79.0)
# DeltaFrames to EndZone (Robo,Fish)=(257.0,78.0)
#    Trial  Robo Time To EndZone  Fish Time To EndZone  Avg. Dist  \
# 0  trial                  25.7                   7.8   18.10295
#
#    Robo Avg. Speed  Robo Avg. Speed EndZone  Robo LeadTime  Robo FollowTime  \
# 0            9.641                    0.556            0.0             29.8
#
#    Robo LeadRatio  Fish_Avg_Speed  Fish_Avg_Speed_EndZone
# 0             0.0           7.089                   0.546

# %%
#print(agentData.distTarget)
#print(agentData.currTargetVector)
#print(agentData.force_alg)
for i in range(len(targetVectorList)):
    print(targetVectorList[i])
    print("targetMovement{}".format(i),slc.CalcMovementSuccess(POS,params,targetVectorList[i]))
# Out:
# [2000, 0]
# targetMovement0 [0.75057429 0.74453153]
# [-2000, 0]
# targetMovement1 [-0.75047635 -0.74615424]

# %%
a=np.nan
a=1
if(~(np.isnan(a))):
    print("Not NaN")
# Out:
# Not NaN

# %%
finalVecToTarget=params['targetVector']-POS[-1]
finalDistToTarget=np.linalg.norm(finalVecToTarget,2,axis=1)
print(finalVecToTarget)
print(finalDistToTarget)
# Out:
# [[174.56277226  31.9332917 ]
#  [185.48955026  35.46259143]]
# [177.45956322 188.84906314]

# %%
a=np.arange(0,51,3)
b=np.ones(len(a))*18
leadershipRangeList=list(zip(a,b))
tmp=np.zeros(2)
tmp=np.array(leadershipRangeList[5][:])
print(tmp)
# Out:
# [15. 18.]

# %%
POS=np.zeros((2,2,2))
phi0=np.pi/3.
phi1=0.0
POS[1,0,:]=s*t*np.array([np.cos(phi0),np.sin(phi0)])
POS[1,1,:]=s*t*np.array([np.cos(phi1),np.sin(phi1)])

slc.CalcLeadingSuccess(POS,params,targetVector=[1000,0])
# Out:
# array([0.5, 1. ])

# %%
# Out:
# 200.0

# %%
outdata['all_displacements_vec']
# Out:
# array([[228.94167554, 146.56845616],
#        [251.42955689, 166.4428265 ]])

# %%
outdata['all_displacements_vec']
outdata['avg_displacements_vec']
# Out:
# array([459.54365402, 178.89319617])

# %%
from sklearn.preprocessing import normalize 
targetVectors=np.nan*np.ones((params['N'],2))
for i in range(len(params['targetVectorList'])):
    targetVectors[i]=params['targetVectorList'][i]
            
    targetUnitVector=targetVectors[i]/np.linalg.norm(targetVectors[i])
    all_displacements_vec=(POS[-1,:,:]-POS[0,:,:])
    all_displacements=np.linalg.norm(np.multiply(all_displacements_vec,targetUnitVector),axis=1)

# %%
print(all_displacements_vec)
print(all_displacements)
# Out:
# [[551.1766325  -61.63021402]
#  [545.8484572  -68.50025724]]
# [551.1766325 545.8484572]

# %%
outdata.keys()
pos=outdata['pos']
print(np.shape(pos))
# Out:
# (5001, 2, 2)

# %%
tidx=1000
print(POS[tidx,0,:])
print(POS[tidx,1,:])
print(pos[tidx][0,:])
print(pos[tidx][1,:])
# Out:
# [-76.62895883 115.37205153]
# [-91.68066937 -15.5297242 ]
# [11.37104117 27.37205153]
# [84.31933063 72.4702758 ]

# %%
f.savefig("/mnt/DATA/leadershipModel/exampleTraj_leadZ_{}_noise_{}.png".format(leadershipRange,noisep),dpi=300)

# %%
df=pd.DataFrame(columns=['time','xL','yL','xF','yF','leadMode'])
df['time']=timearray[::5]
df['xL']=POS[:-1,0,0]
df['yL']=POS[:-1,0,1]
df['xF']=POS[:-1,1,0]
df['yF']=POS[:-1,1,1]
df['leadMode']=leadingRecord[::5]

# %%
len(POS[:,0,0])
len(timearray[::5])
# Out:
# 5000

# %%
circlepoints=20
radius=5
c=params['targetVector']
theta=np.linspace(0,2*np.pi,circlepoints)
f=figure()
subplots(1,2)
subplot(121,aspect='equal')
plot(df['xL'],df['yL'],'-')
plot(df[df.leadMode==0]['xL'],df[df.leadMode==0]['yL'],'r.',markersize=1)
plot(c[0]+radius*np.cos(theta),c[1]+radius*np.sin(theta),"m-")
xlabel("position x")
ylabel("position y")
#xlim([0,88])
#ylim([0,88])
text(8,80,'Leader')

subplot(122,aspect='equal')
plot(df['xF'],df['yF'],'-')
plot(df[df.leadMode==0]['xF'],df[df.leadMode==0]['yF'],'r.',markersize=1)
plot(c[0]+radius*np.cos(theta),c[1]+radius*np.sin(theta),"m-")
xlabel("position x")
text(8,80,'Follower')
#xlim([0,88])
#ylim([0,88])
tight_layout()
#savefig("/mnt/DATA/leadershipModel/exampleTraj_leadZ_{}_noise_{}.png".format(leadershipRange,noisep),dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# --------------------------------------------------------------------------
# KeyError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'xL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                 Traceback (most recent call last)
# <ipython-input-16-4bdc379459c7> in <module>
#       6 subplots(1,2)
#       7 subplot(121,aspect='equal')
# ----> 8 plot(df['xL'],df['yL'],'-')
#       9 plot(df[df.leadMode==0]['xL'],df[df.leadMode==0]['yL'],'r.',markersize=1)
#      10 plot(c[0]+radius*np.cos(theta),c[1]+radius*np.sin(theta),"m-")
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'xL'

# %%
figure(figsize=(10,10))
subplot(aspect='equal')
plot(df['xL'],df['yL'],'-')
plot(df['xF'],df['yF'],'-')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# --------------------------------------------------------------------------
# KeyError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'xL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                 Traceback (most recent call last)
# <ipython-input-17-761086be249c> in <module>
#       1 figure(figsize=(10,10))
#       2 subplot(aspect='equal')
# ----> 3 plot(df['xL'],df['yL'],'-')
#       4 plot(df['xF'],df['yF'],'-')
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'xL'

# %%
#POS=np.array(outdata['POS'])
#pos=np.array(outdata['pos'])
#print(shape(POS))
#figure(figsize=(20,3))
#subplot(aspect='equal')
#plot(POS[:,0,0],POS[:,0,1])
#plot(pos[:,0,0],pos[:,0,1])

# %%
outdata['finalStep']*params['dt']
# Out:
# 36.35

# %%
# Plot Leading Ratio versus time
leadingRecord=outdata['leadingRecord'][:,:].T
timearray=np.arange(len(leadingRecord))*params['dt']
plot(timearray,leadingRecord)
ylim([-0.05,1.05])
xlabel("simulation time")
ylabel("leading variable")
leading_ratio=np.sum(outdata['leadingRecord'][0])/len(outdata['leadingRecord'][0])
print("LeadingRatio={}".format(leading_ratio))
# Out:
# LeadingRatio=0.2628

# %%
POS=np.array(outdata['POS'])
np.shape(POS)
distVec=POS[:,0,:]-POS[:,1,:]
plot(np.linalg.norm(distVec,axis=1))

# %%
#print(outdata['leadingTime'])
#print(outdata.keys())
agentData.sigmap**2/dt
# Out:
# array([ 0.1,  1. ])

# %%
params['L']
POS=np.array(outdata['POS'])
figure(figsize=(20,10))
subplot(aspect='equal')
plot(POS[:,:,0],POS[:,:,1],'k')
plot(POS[:,0,0],POS[:,:params['leaderCount'],1],'r')

# Calculate total displacement along X as measure of leadership success
total_displacements_in_X=POS[-1,:,0]-POS[0,:,0]
print(total_displacements_in_X)
avg_total_displacement=np.mean(total_displacements_in_X)
print(avg_total_displacement)
xlabel("total position x")
ylabel("total position y")
# Out:
# [ 95.39189277  85.28049831]
# 90.3361955385

# %%
subplot(aspect='equal')
plot(agentData.pos[1,0]-agentData.pos[0,0],agentData.pos[1,1]-agentData.pos[0,1],"bo")
quiver(agentData.pos[:,0]-agentData.pos[0,0],agentData.pos[:,1]-agentData.pos[0,1],agentData.uv[:,0],agentData.uv[:,1],scale=2)
distM,dX,dY=slc.CalcDistVecMatrix(agentData.pos,1000,-2)
approachPointX=-dX[0,1]+agentData.uv[1,0]
approachPointY=-dY[0,1]+agentData.uv[1,1]
plot(approachPointX,approachPointY,"bx")

# %%
params["leader_noisep"]=0.0
agentData.sigmap[:params['leaderCount']]=np.ones(params['leaderCount'])*np.sqrt(2.*params['dt']*params["leader_noisep"]);

print(agentData.sigmap)
# Out:
# [ 0.          0.14142136]

# %%
# Calculate Leading Performance for a run
outdata=slc.CalcLeadingPerformance(outdata,params,ignore_timepoints=0)
# Out:
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 9.86911116]
# tot_avgdist      = 9.86911115934609
# all_finaldist    = [ 10.31422544]
# tot_finaldist    = 10.314225438676756
# leadRatio        = 0.6655844155844156
# leadingTime      = [ 24.64]
# avg_displacement = 91.02001713546939
# lead_displacement = [ 0.61628073  5.46734219]
# fish_displacement = [[-10.8694636    6.08740603]]
# -----------------------------------
# proj_lead_displacements = 5.501966243866211
# proj_fish_displacements = [ 12.45799949]
# -----------------------------------

# %%
print(np.linalg.norm(outdata['lead_displacement']))
# Out:
# 94.6564479392

# %%
#targetUnitVector=np.ones(2)/np.sqrt(2.)
#all_displacements=outdata['all_displacements']
#prod=(np.multiply(all_displacements,targetUnitVector))
#print(prod)
#print(np.linalg.norm(prod,axis=1))
#print(all_displacements*1./np.sqrt(2.))

# %%
# All results can be accessed in outdata
print("Average distance to leader: {}".format(outdata['tot_avgdist'][0]))
print("Lead Ratio: {}".format(outdata['leadRatio'][0]))
print("Average displacement in x-direction: {}".format(outdata['avg_displacement'][0]))
# Out:
# Average distance to leader: 10.265166473961166
# Lead Ratio: 0.59488
# Average displacement in x-direction: 78.89957848439653

# %%
#agentData.leading[1]=0
print(agentData.force_alg)
print(agentData.timer)
# Out:
# [[ 0.03239109 -0.99947527]
#  [ 0.          0.        ]]
# [0.]

# %% [markdown]
# # Parallel Run

# %%
para1name='leader_algstrength'
para2name='leadershipRangeList'
para1values=[4]
para2values=[[0,12],[12,12]]

# %%
outdata=slc.SingleRun(params,agentData)
# Out:
# Performing a single run.
# initialPosLeader=[[ 200.51799674  108.37659888]]
# Leading distance 100.0 reached by all leaders! Stopping Simulation.
# finalPosLeader=[[ 200.56773001  108.37144122]]
# Done!
# SozialerLeader/SwarmLeadershipCouzin.py:483: RuntimeWarning: invalid value encountered in true_divide
#   dUX=np.divide(dX,distmatrix)
# SozialerLeader/SwarmLeadershipCouzin.py:484: RuntimeWarning: invalid value encountered in true_divide
#   dUY=np.divide(dY,distmatrix)

# %%
params['leaderCount']
# Out:
# 1

# %%
# Running Parameter Scan on Mmltiple threads in parallel
#params=slc.InitParams(time=500,BC=-2)
outdata_list,para_list=slc.RunParallelScan(para1name,para2name,
                                           para1values,para2values,
                                           runs=3,params=params,agentData=agentData);
# Out:
# leader_algstrength 4
# -----------------------------------------------
# ValueError    Traceback (most recent call last)
# <ipython-input-9-6b2bfe1a46e9> in <module>
#       1 # Running Parameter Scan on Mmltiple threads in parallel
#       2 #params=slc.InitParams(time=500,BC=-2)
# ----> 3 outdata_list,para_list=slc.RunParallelScan(para1name,para2name,
#       4                                            para1values,para2values,
#       5                                            runs=3,params=params,agentData=agentData);
#
# ~/Dropbox/work/Projects/inProgress/RobofishLeadership/code/SwarmLeadershipCouzin.py in RunParallelScan(para1name, para2name, para1values, para2values, runs, params, agentData, n_proc)
#    1241                 tmp_params[para2name]=p2
#    1242                 tmp_params['run']=r
# -> 1243                 tmp_agentData=AgentData(tmp_params)
#    1244                 InitAgents(tmp_agentData,tmp_params)
#    1245                 params_list.append(tmp_params)
#
# ~/Dropbox/work/Projects/inProgress/RobofishLeadership/code/SwarmLeadershipCouzin.py in __init__(self, params)
#      82                     print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
#      83                     print("WARNING!!! Less desiredPhi than leaders!!!!")
# ---> 84                 self.leadershipRange[:len(leadershipRangeList)]=leadershipRangeList;
#      85             else:
#      86                 self.leadershipRange=np.ones(leaderCount)*params['leadershipRange']
#
# ValueError: cannot copy sequence with size 2 to array axis with dimension 1

# %%
#data=pkl.load(open("/home/prom/DATA/leadershipModel/leadershipRange_8_84_noisep_1.0_2.0.h5","rb"))

# %%
#fish parameter

N=2;              # default parameter 300
L=3000                # default parameter 50
L=88
time=300.0          # default parameter 300
dt=0.05             # default parameter 0.05

BC=1               # default parameter 0, reflecting 1
IC=1               # initial condition
targetType=2
leadingDistance=2000;

factor=1.0
speed0=factor*10.0

repstrength=factor*5.0     # default parameter 5.0
algstrength=factor*0.0     # default parameter 1.0
attstrength=factor*2.0     # default parameter 0.5
noisep=5.0;                # default parameter 0.2

attstrengthDist=0

reprange=3.0        # default parameter 1.0
algrange=10.0       # default parameter 5.0
attrange=20.0       # default parameter 25.0


#singleLeader=True
leaderCount=2
leadershipRange=16
recruitingRange=8
recruitingAttStrength=factor*10.0
recruitingTime=dt
recruitingSpeed=1.0*speed0

leader_repstrength=repstrength
leader_algstrength=factor*4.0
leader_attstrength=2.*attstrength    

leader_reprange=reprange
leader_algrange=0.5
leader_attrange=1000.0

leader_noisep=noisep

leader_desiredPhi=[0.0]
#leader_desiredPhi=[0.0,None]

leadershipRangeList=[leadershipRange]
#leadershipRangeList=[leadershipRange,12]

#targetVectorList=[[2000,0]]
targetVectorList=[[80,80]]
#targetVectorList=[[2000,0],[-2000,0]]

if(leaderCount>1):
    leadershipRangeList=[leadershipRange,leadershipRange]
    #leader_desiredPhi=[0.0,np.pi]
    leader_desiredPhi=[0.0,None]
else:
    leadershipRangeList=[leadershipRange]
    leader_desiredPhi=[0.0]

dist_dependence='zone'
int_type='matrix'
output=0.5

#dist_dependence='overlap'
#dist_dependence='zone'

#if(targetType==2):
#    L=88                 # size experimental tank 
#    IC=1
#    BC=1
#    attrange=100
#    attstrength=0

# initialize system parameters
params=slc.InitParams(N=N,L=L,time=time,dt=dt,BC=BC,IC=IC,output=output,int_type=int_type,speed0=speed0,                               
                        repstrength=repstrength,reprange=reprange,
                        algstrength=algstrength,algrange=algrange,
                        attstrength=attstrength,attrange=attrange,
                        attstrengthDist=attstrengthDist,
                        noisep=noisep,
                        targetType=targetType,targetVectorList=targetVectorList,
                        leader_noisep=leader_noisep,
                        leaderCount=leaderCount,leadershipRange=leadershipRange,leadingDistance=leadingDistance,
                        recruitingRange=recruitingRange,recruitingTime=recruitingTime,
                        recruitingAttStrength=recruitingAttStrength,recruitingSpeed=recruitingSpeed,
                        leader_repstrength=leader_repstrength,leader_algstrength=leader_algstrength,leader_attstrength=leader_attstrength,
                        leader_reprange=leader_reprange,leader_algrange=leader_algrange,leader_attrange=leader_attrange,
                        leader_desiredPhi=leader_desiredPhi
                        )

#########################################
agentData=slc.AgentData(params)
slc.InitAgents(agentData,params)
###########################################
#if(leaderCount>0):
#        
#        agentData.repstrength[:leaderCount]=leader_repstrength
#        agentData.algstrength[:leaderCount]=leader_algstrength
#        agentData.attstrength[:leaderCount]=leader_attstrength
#
#        agentData.reprange[:leaderCount]=leader_reprange
#        agentData.algrange[:leaderCount]=leader_algrange
#        agentData.attrange[:leaderCount]=leader_attrange
#


para1name="leadershipRange"
#para1values=[0,8,10,12,14,16,18,20,22,24,24,26]
#para1values=np.arange(6.,37.,2.0)
para1values=np.arange(0.,74.0,12.0)
#para1val_addon=np.array([0,48,60,72])

random_range=True

if(leaderCount>1):
    para1name="leadershipRangeList"
    array1=para1values
    array2=np.ones(len(array1))*leadershipRange

    para1values=np.array(tuple(zip(array1,array2)))

    

#para2name="noisep"
para2name="leader_algstrength"
#para2name="recruitingAttStrength"
#para2values=factor*np.array([0.5])
para2values=factor*np.array([8.0,12.0,16.0])

runs=2
n_proc=10

outpath='/home/prom/work/Leadership/DATA/'
outname="targetType{}_Nl{}_S{}_".format(targetType,leaderCount,speed0)+para1name+"_{}_{}".format(np.min(para1values),np.max(para1values))+"_"+para2name+"_{}_{}".format(np.min(para2values),np.max(para2values))

outparams=outpath+'para_'+outname+'.pkl'
outresult=outpath+outname+'.h5'

#####################################################################
print("N    = %d" % params['N'])
print("L    = %d" % params['L'])
print("Nl   = %d" % params['leaderCount'])
print("time = %g" % params['time'])

print("outresult={}".format(outresult))
print("outparams={}".format(outparams))

print("--------------------------------------------------------")
print("runs per para set={}".format(runs)) 
print("{} = {}".format(para1name,para1values))
print("{} = {}".format(para2name,para2values))
print("total number of runs= {}".format(len(para1values)*len(para2values)*runs))
print("--------------------------------------------------------")
input("Press Enter to continue...")
##########################################################################

outdata_list,para_list=slc.RunParallelScan(para1name,para2name,para1values,para2values,runs=runs,params=params,agentData=agentData,n_proc=n_proc)
# Out:
# recruiting speed=10.0
# N    = 2
# L    = 88
# Nl   = 2
# time = 300
# outresult=/home/prom/work/Leadership/DATA/targetType2_Nl2_S10.0_leadershipRangeList_0.0_72.0_leader_algstrength_8.0_16.0.h5
# outparams=/home/prom/work/Leadership/DATA/para_targetType2_Nl2_S10.0_leadershipRangeList_0.0_72.0_leader_algstrength_8.0_16.0.pkl
# --------------------------------------------------------
# runs per para set=2
# leadershipRangeList = [[ 0. 16.]
#  [12. 16.]
#  [24. 16.]
#  [36. 16.]
#  [48. 16.]
#  [60. 16.]
#  [72. 16.]]
# leader_algstrength = [ 8. 12. 16.]
# total number of runs= 42
# --------------------------------------------------------
# Press Enter to continue...
# leadershipRangeList [ 0. 16.]
# leadershipRangeList [ 0. 16.]
# leadershipRangeList [ 0. 16.]
# leadershipRangeList [ 0. 16.]
# leadershipRangeList [ 0. 16.]
# leadershipRangeList [ 0. 16.]
# leadershipRangeList [12. 16.]
# leadershipRangeList [12. 16.]
# leadershipRangeList [12. 16.]
# leadershipRangeList [12. 16.]
# leadershipRangeList [12. 16.]
# leadershipRangeList [12. 16.]
# leadershipRangeList [24. 16.]
# leadershipRangeList [24. 16.]
# leadershipRangeList [24. 16.]
# leadershipRangeList [24. 16.]
# leadershipRangeList [24. 16.]
# leadershipRangeList [24. 16.]
# leadershipRangeList [36. 16.]
# leadershipRangeList [36. 16.]
# leadershipRangeList [36. 16.]
# leadershipRangeList [36. 16.]
# leadershipRangeList [36. 16.]
# leadershipRangeList [36. 16.]
# leadershipRangeList [48. 16.]
# leadershipRangeList [48. 16.]
# leadershipRangeList [48. 16.]
# leadershipRangeList [48. 16.]
# leadershipRangeList [48. 16.]
# leadershipRangeList [48. 16.]
# leadershipRangeList [60. 16.]
# leadershipRangeList [60. 16.]
# leadershipRangeList [60. 16.]
# leadershipRangeList [60. 16.]
# leadershipRangeList [60. 16.]
# leadershipRangeList [60. 16.]
# leadershipRangeList [72. 16.]
# leadershipRangeList [72. 16.]
# leadershipRangeList [72. 16.]
# leadershipRangeList [72. 16.]
# leadershipRangeList [72. 16.]
# leadershipRangeList [72. 16.]
# Performing a single run.Performing a single run.Performing a single run.
#
# Performing a single run.
# Performing a single run.
#
# Performing a single run.
# Performing a single run.Performing a single run.
#
# Performing a single run.
# Performing a single run.
# Target reached!
# params[leadingDistance]=2000
# i=0,s=209
# agentData.POS[0]=[76.96855223 77.05681146]
# agentData.initpos[0]=[0.86638524 9.55500669]
# agentData.distTarget[0]=4.724513305124294
# agentData.leadingTime[0]=10.450000000000001
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 209
# finalStep=209, finalPosLeader=[[76.96855223 77.05681146]
#  [63.53315077 70.71306362]]
# Done!
# Performing a single run.
# Target reached!
# params[leadingDistance]=2000
# i=0,s=211
# agentData.POS[0]=[76.89735509 77.44077783]
# agentData.initpos[0]=[2.52133436 6.51954541]
# agentData.distTarget[0]=4.520269288094021
# agentData.leadingTime[0]=10.55
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 211
# finalStep=211, finalPosLeader=[[76.89735509 77.44077783]
#  [63.3735926  71.37169982]]
# Done!
# Performing a single run.
# Target reached!
# params[leadingDistance]=2000
# i=0,s=209
# agentData.POS[0]=[76.58752644 77.29222165]Target reached!
#
# params[leadingDistance]=2000
# agentData.initpos[0]=[3.09296684 5.62393623]
# i=0,s=205agentData.distTarget[0]=4.855390043878267
# agentData.leadingTime[0]=10.450000000000001
#
# agentData.targetVector[0]=[80. 80.]
# agentData.POS[0]=[76.74921922 77.09382952]
# agentData.initpos[0]=[9.07326219 1.36443976]
# agentData.distTarget[0]=4.860415241620192
# Distance to target 5 reached by all leaders! Stopping Simulation.agentData.leadingTime[0]=10.25
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
#
# 209
# finalStep=209, finalPosLeader=[[76.58752644 77.29222165]
#  [68.3996614  67.87754593]]
# Done!
# Performing a single run.
# 205
# finalStep=205, finalPosLeader=[[76.74921922 77.09382952]
#  [69.67520825 67.19722511]]
# Target reached!Done!Target reached!
# params[leadingDistance]=2000
#
# i=0,s=294
# agentData.POS[0]=[76.7842548 77.0504178]
#
# Performing a single run.
# params[leadingDistance]=2000agentData.initpos[0]=[6.56034782 6.68823624]
# agentData.distTarget[0]=4.823970584803782
# Target reached!
# params[leadingDistance]=2000
# i=0,s=322agentData.leadingTime[0]=14.700000000000001
#
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 294
# i=0,s=287
# finalStep=294, finalPosLeader=[[76.7842548  76.87975067]
#  [87.97972857 84.66371254]]
# Done!
# Performing a single run.agentData.POS[0]=[76.79653544 83.00545767]
#
# agentData.POS[0]=[75.78134399 80.51376729]agentData.initpos[0]=[0.57941157 6.39184621]
# agentData.distTarget[0]=4.834721644933817
#
#
# agentData.initpos[0]=[8.372179  7.8161422]agentData.leadingTime[0]=16.1
#
# agentData.distTarget[0]=4.749780100540077agentData.targetVector[0]=[80. 80.]
# Target reached!
# Distance to target 5 reached by all leaders! Stopping Simulation.agentData.leadingTime[0]=14.350000000000001
# 322
#
# finalStep=322, finalPosLeader=[[77.16619463 82.48355468]
#  [80.04364113 78.06932107]]agentData.targetVector[0]=[80. 80.]
#
# Done!
#
# params[leadingDistance]=2000
# Distance to target 5 reached by all leaders! Stopping Simulation.
#
# i=0,s=208287agentData.POS[0]=[76.86821054 77.38755386]
# finalStep=287, finalPosLeader=[[75.78134399 80.10677388]
#  [80.43314369 76.82478775]]
# Done!
#
# agentData.initpos[0]=[4.91417133 7.63569243]
# agentData.distTarget[0]=4.578179433313328
# agentData.leadingTime[0]=10.4
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 208Performing a single run.Performing a single run.
#
# finalStep=208, finalPosLeader=[[76.86821054 77.38755386]
#  [62.36047526 75.00571201]]
# Done!
# Performing a single run.
#
# Target reached!
# params[leadingDistance]=2000
# i=0,s=212
# agentData.POS[0]=[76.80091012 76.92536044]
# agentData.initpos[0]=[3.49675398 4.46626598]
# agentData.distTarget[0]=4.937068323148037
# agentData.leadingTime[0]=10.600000000000001
# agentData.targetVector[0]=[80. 80.]
# Target reached!Distance to target 5 reached by all leaders! Stopping Simulation.
#
# params[leadingDistance]=2000
# i=0,s=197212
# agentData.POS[0]=[78.81886151 75.49812499]
# agentData.initpos[0]=[7.86019879 8.84696416]
# agentData.distTarget[0]=4.961241297552293
# agentData.leadingTime[0]=9.850000000000001
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
#
# finalStep=212, finalPosLeader=[[76.80091012 76.92536044]
#  [65.84588163 73.79717708]]197
#
# finalStep=197, finalPosLeader=[[78.81886151 75.49812499]
#  [60.39904318 69.46476088]]Done!
# Done!
#
# Performing a single run.
# Performing a single run.
# Target reached!
# params[leadingDistance]=2000
# i=0,s=194
# agentData.POS[0]=[77.74534914 76.4927604 ]
# agentData.initpos[0]=[8.08002262 9.93703715]
# agentData.distTarget[0]=4.588282766506897
# agentData.leadingTime[0]=9.700000000000001
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# Target reached!194
# params[leadingDistance]=2000
# i=0,s=201
# agentData.POS[0]=[77.5774505  76.27747342]
# agentData.initpos[0]=[3.85541252 8.70679486]
#
# agentData.distTarget[0]=4.94137206935486finalStep=194, finalPosLeader=[[77.74534914 76.4927604 ]
#  [57.62775738 69.36530616]]
#
# Done!
# agentData.leadingTime[0]=10.05
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 201
# finalStep=201, finalPosLeader=[[77.5774505  76.27747342]
#  [79.07297093 64.29978853]]Performing a single run.
#
# Done!
# Performing a single run.
# Target reached!
# Target reached!params[leadingDistance]=2000
# params[leadingDistance]=2000
#
# i=0,s=312
# agentData.POS[0]=[75.57628255 78.91953554]
# agentData.initpos[0]=[4.05515501 1.76001662]
# agentData.distTarget[0]=4.975581353461474
# agentData.leadingTime[0]=15.600000000000001i=0,s=213
# Target reached!agentData.POS[0]=[77.88876518 76.50315658]
# agentData.initpos[0]=[4.71954329 3.52653723]
# agentData.distTarget[0]=4.584673437129825
# agentData.leadingTime[0]=10.65
# agentData.targetVector[0]=[80. 80.]
#
#
# agentData.targetVector[0]=[80. 80.]Distance to target 5 reached by all leaders! Stopping Simulation.params[leadingDistance]=2000
#
# i=0,s=202
# Distance to target 5 reached by all leaders! Stopping Simulation.agentData.POS[0]=[77.25761101 76.52520921]
# 312
#
# finalStep=312, finalPosLeader=[[75.69910104 78.71668925]
#  [83.44811749 79.19179896]]agentData.initpos[0]=[7.74778173 4.95291411]
#
# agentData.distTarget[0]=4.908963653479629Done!
#
# Performing a single run.
# agentData.leadingTime[0]=10.100000000000001
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
#
# 213
# finalStep=213, finalPosLeader=[[77.88876518 76.50315658]
#  [70.73000155 63.0660199 ]]202
# Done!
#
# finalStep=202, finalPosLeader=[[77.25761101 76.52520921]
#  [67.88066097 65.65742119]]
# Done!
# Performing a single run.
# Performing a single run.
# Target reached!
# params[leadingDistance]=2000
# i=0,s=211
# agentData.POS[0]=[78.5510384  75.86061083]
# agentData.initpos[0]=[8.87707201 0.48295447]
# agentData.distTarget[0]=4.816608703880459
# agentData.leadingTime[0]=10.55
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.Target reached!
#
# params[leadingDistance]=2000
# 211
# i=0,s=204
# finalStep=211, finalPosLeader=[[78.5510384  76.06150707]
#  [69.1188602  63.51468629]]
# Done!
# Performing a single run.
# agentData.POS[0]=[77.11760135 76.66314122]
# agentData.initpos[0]=[9.93730054 1.19214272]
# agentData.distTarget[0]=4.909371281478066
# agentData.leadingTime[0]=10.200000000000001
# agentData.targetVector[0]=[80. 80.]Target reached!
# params[leadingDistance]=2000
# i=0,s=874
# agentData.POS[0]=[75.73594392 80.68715033]
#
# Distance to target 5 reached by all leaders! Stopping Simulation.agentData.initpos[0]=[3.7079138  8.68855516]
#
# agentData.distTarget[0]=4.813146728569025
# agentData.leadingTime[0]=43.7204
# finalStep=204, finalPosLeader=[[77.11760135 76.66314122]
#  [64.96183271 71.68425889]]
# Done!
# Performing a single run.
#
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# Target reached!874
# Target reached!finalStep=874, finalPosLeader=[[75.45459938 80.26917725]
#  [76.46089461 81.48624414]]
# Done!
# params[leadingDistance]=2000
# i=0,s=209
# agentData.POS[0]=[77.08918404 76.87646466]
# agentData.initpos[0]=[2.35877019 4.53915994]
# agentData.distTarget[0]=4.769431054859699
# agentData.leadingTime[0]=10.450000000000001
#
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 209
# finalStep=209, finalPosLeader=[[77.08918404 76.87646466]
#  [61.91197146 71.01950293]]
# params[leadingDistance]=2000
# Done!Performing a single run.
#
#
# Performing a single run.
# i=0,s=194
# agentData.POS[0]=[76.87778076 76.90396677]
# agentData.initpos[0]=[7.93597982 9.90004465]
# agentData.distTarget[0]=4.896962952086717
# agentData.leadingTime[0]=9.700000000000001
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 194
# finalStep=194, finalPosLeader=[[76.87778076 76.90396677]
#  [62.25559129 72.78756102]]
# Done!
# Target reached!
# params[leadingDistance]=2000
# i=0,s=217
# agentData.POS[0]=[77.12454767 77.20438658]
# agentData.initpos[0]=[4.71512979 4.1975362 ]
# agentData.distTarget[0]=4.509940515273834
# Performing a single run.agentData.leadingTime[0]=10.850000000000001
# agentData.targetVector[0]=[80. 80.]
#
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 217
# finalStep=217, finalPosLeader=[[77.12454767 77.20438658]
#  [59.60520189 70.75516009]]
# Done!
# Target reached!Performing a single run.
# params[leadingDistance]=2000
#
# i=0,s=216
# agentData.POS[0]=[77.11473708 77.18678089]
# agentData.initpos[0]=[0.0372514  2.18665219]
# agentData.distTarget[0]=4.528525847564365
# agentData.leadingTime[0]=10.8
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 216
# finalStep=216, finalPosLeader=[[77.11473708 77.18678089]
#  [57.172271   77.9597363 ]]
# Done!
# Performing a single run.
# Target reached!
# params[leadingDistance]=2000
# i=0,s=759
# agentData.POS[0]=[76.64433074 77.13689969]Target reached!
# agentData.initpos[0]=[3.18485954 4.46724506]
# agentData.distTarget[0]=4.90432460632389
#
# agentData.leadingTime[0]=37.95
# params[leadingDistance]=2000agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 759
# finalStep=759, finalPosLeader=[[77.37559054 76.93166788]
#  [77.92815848 79.94412167]]
# Done!
# Target reached!
# params[leadingDistance]=2000
# i=0,s=209
# agentData.POS[0]=[77.01854288 76.78321707]
#
# agentData.initpos[0]=[7.22234606 3.50755359]
# agentData.distTarget[0]=4.885465766579764
# agentData.leadingTime[0]=10.450000000000001
# agentData.targetVector[0]=[80. 80.]
# i=0,s=823
# agentData.POS[0]=[80.1815916  75.60728569]
# agentData.initpos[0]=[4.74030214 1.10562164]
# agentData.distTarget[0]=4.8960880839283325
# agentData.leadingTime[0]=41.150000000000006Performing a single run.Distance to target 5 reached by all leaders! Stopping Simulation.
#
# 209
# finalStep=209, finalPosLeader=[[77.01854288 76.78321707]
#  [72.36329046 58.42958882]]
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 823
#
# Done!
# Performing a single run.
# finalStep=823, finalPosLeader=[[80.20931302 76.14139515]
#  [80.40044444 74.60003574]]Target reached!
# params[leadingDistance]=2000
# i=0,s=198
# agentData.POS[0]=[77.05476252 76.97996946]
# agentData.initpos[0]=[6.85820804 7.91016857]
# agentData.distTarget[0]=4.717225267226789
# agentData.leadingTime[0]=9.9
#
# Done!agentData.targetVector[0]=[80. 80.]
# 198
# Distance to target 5 reached by all leaders! Stopping Simulation.
# Performing a single run.
#
# finalStep=198, finalPosLeader=[[77.05476252 76.97996946]
#  [70.67339756 62.78100216]]
# Done!
# Target reached!
# Target reached!
# params[leadingDistance]=2000
# i=0,s=211
# params[leadingDistance]=2000agentData.POS[0]=[77.32228096 76.59961634]
# i=0,s=263
#
# agentData.POS[0]=[83.23795716 77.30117832]Target reached!
# params[leadingDistance]=2000
# i=0,s=220
# agentData.POS[0]=[77.64688691 76.36965972]
# agentData.initpos[0]=[8.76408775 4.34854543]
#
# agentData.distTarget[0]=4.825576970391134
# agentData.leadingTime[0]=11.0
# agentData.targetVector[0]=[80. 80.]
# agentData.initpos[0]=[4.13415229 1.50588482]Distance to target 5 reached by all leaders! Stopping Simulation.
#
# 220agentData.distTarget[0]=4.817281357212288
# agentData.leadingTime[0]=10.55
# agentData.initpos[0]=[0.97715913 6.3761105 ]agentData.targetVector[0]=[80. 80.]
#
# agentData.distTarget[0]=4.691517660859693
# agentData.leadingTime[0]=13.15
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
#
# 211
# finalStep=220, finalPosLeader=[[77.64688691 76.84134586]
#  [73.42845466 58.58318416]]finalStep=211, finalPosLeader=[[77.32228096 76.59961634]
#  [72.18469674 68.0182346 ]]
#
# Done!Done!
#
# Performing a single run.Performing a single run.
#
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 263
# finalStep=263, finalPosLeader=[[83.05805672 77.30117832]
#  [72.89476223 72.42976669]]
# Done!
# Target reached!
# params[leadingDistance]=2000
# i=0,s=213
# agentData.POS[0]=[77.03370626 76.6166641 ]
# agentData.initpos[0]=[1.12740064 2.75025112]
# agentData.distTarget[0]=4.997873557927381
# agentData.leadingTime[0]=10.65
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 213
# finalStep=213, finalPosLeader=[[77.03370626 76.6166641 ]
#  [77.37745528 61.94566215]]
# Done!
# Performing a single run.
# Target reached!
# params[leadingDistance]=2000Target reached!
# i=0,s=211
#
# params[leadingDistance]=2000agentData.POS[0]=[76.71122038 76.9371173 ]
#
# i=0,s=204
# agentData.POS[0]=[76.90407037 77.3981914 ]Target reached!
#
# params[leadingDistance]=2000agentData.initpos[0]=[4.494999   8.28276581]
# i=0,s=202
#
# agentData.POS[0]=[76.8070929  77.20444696]agentData.distTarget[0]=4.543465954130079
#
# agentData.initpos[0]=[8.77761816 3.27260618]
# agentData.leadingTime[0]=10.200000000000001agentData.distTarget[0]=4.735839120542764
#
# agentData.leadingTime[0]=10.100000000000001agentData.targetVector[0]=[80. 80.]
#
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 204agentData.initpos[0]=[1.11300538 4.49541431]202
#
# agentData.distTarget[0]=4.994077301852431
# finalStep=204, finalPosLeader=[[76.90407037 77.3981914 ]
#  [62.36750417 69.91121903]]
#
# agentData.leadingTime[0]=10.55Done!finalStep=202, finalPosLeader=[[76.8070929  77.20444696]
#  [66.07739478 58.31853822]]
#
# Performing a single run.
# agentData.targetVector[0]=[80. 80.]
#
# Done!
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 211
# finalStep=211, finalPosLeader=[[76.71122038 76.9371173 ]
#  [68.17271705 66.38395466]]
# Done!
# Performing a single run.
# Target reached!
# params[leadingDistance]=2000
# i=0,s=216
# agentData.POS[0]=[77.21495493 77.12111206]
# agentData.initpos[0]=[3.42483651 1.88686595]
# agentData.distTarget[0]=4.5048654729456254
# agentData.leadingTime[0]=10.8
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 216
# finalStep=216, finalPosLeader=[[77.21495493 77.12111206]
#  [82.45375993 55.01615565]]
# Done!
# Target reached!
# params[leadingDistance]=2000
# i=0,s=216
# agentData.POS[0]=[77.27896625 76.77202031]
# agentData.initpos[0]=[8.22684168 3.16086089]
# agentData.distTarget[0]=4.720135823619405
# agentData.leadingTime[0]=10.8
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 216
# finalStep=216, finalPosLeader=[[77.27896625 76.77202031]
#  [71.04669147 59.18801071]]
# Done!
# Target reached!
# params[leadingDistance]=2000
# i=0,s=209Target reached!
#
# agentData.POS[0]=[77.03185829 77.14698342]params[leadingDistance]=2000
#
# i=0,s=214
# agentData.initpos[0]=[8.40256148 1.27906071]agentData.POS[0]=[76.83673315 76.93294603]
#
# agentData.distTarget[0]=4.602150871170481agentData.initpos[0]=[2.81921984 3.69732606]
#
# agentData.distTarget[0]=4.905928065966253agentData.leadingTime[0]=10.450000000000001
#
# agentData.leadingTime[0]=10.700000000000001agentData.targetVector[0]=[80. 80.]
#
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.Distance to target 5 reached by all leaders! Stopping Simulation.
#
# 214209
#
# finalStep=209, finalPosLeader=[[77.03185829 77.14698342]
#  [61.32515841 57.63876924]]
# finalStep=214, finalPosLeader=[[76.83673315 76.93294603]
#  [76.01697375 72.98230729]]
#
# Done!Done!
# Target reached!
# params[leadingDistance]=2000
# i=0,s=198
# agentData.POS[0]=[77.00922217 76.76519194]
# agentData.initpos[0]=[9.19172016 5.08690927]
# agentData.distTarget[0]=4.9051709769604726
# agentData.leadingTime[0]=9.9
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 198
# finalStep=198, finalPosLeader=[[77.00922217 76.76519194]
#  [75.80802614 60.82946062]]
# Done!
# Target reached!
# params[leadingDistance]=2000
# i=0,s=2433
# agentData.POS[0]=[81.11902792 84.808045  ]
# agentData.initpos[0]=[0.69047941 4.80753093]
# agentData.distTarget[0]=4.957309495955994
# agentData.leadingTime[0]=121.65
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 2433
# finalStep=2433, finalPosLeader=[[79.19266408 82.08200358]
#  [85.5784851  80.67103018]]
# Done!
# Performing a single run.
# Target reached!
# params[leadingDistance]=2000
# i=0,s=1469
# agentData.POS[0]=[83.42148654 76.63201977]
# agentData.initpos[0]=[1.68107931 2.28679265]
# agentData.distTarget[0]=4.958189462071744
# agentData.leadingTime[0]=73.45
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 1469
# finalStep=1469, finalPosLeader=[[81.20166956 75.51974313]
#  [70.12849974 78.7154022 ]]
# Done!
# Target reached!
# params[leadingDistance]=2000
# i=0,s=4270
# agentData.POS[0]=[83.17279865 83.6635794 ]
# agentData.initpos[0]=[0.53926769 5.13885115]
# agentData.distTarget[0]=4.983144543312396
# agentData.leadingTime[0]=213.5
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 4270
# finalStep=4270, finalPosLeader=[[83.53338735 80.7784094 ]
#  [87.93380401 74.16536931]]
# Done!
# Performing a single run.
# Target reached!
# params[leadingDistance]=2000
# i=0,s=1653
# agentData.POS[0]=[75.84957269 77.67369216]
# agentData.initpos[0]=[6.84073705 8.53279639]
# agentData.distTarget[0]=4.906062028230914
# agentData.leadingTime[0]=82.65
# agentData.targetVector[0]=[80. 80.]
# Distance to target 5 reached by all leaders! Stopping Simulation.
# 1653
# finalStep=1653, finalPosLeader=[[74.88166451 78.74083685]
#  [78.44873288 70.23080087]]
# Done!

# %%
idx=1
outdata=outdata_list[idx]
POS=np.array(outdata['POS'])
deltaPOS=POS[:,0,:]-POS[:,1,:]
dist=np.linalg.norm(deltaPOS,axis=1)
print(np.mean(dist))
# Out:
# 8.80247235609155

# %%
x=np.arange(0.0,100.0,0.1)
y1=slc.SigThresh(x,30,-0.05)
y2=slc.LinearFunc(x,30,12)
figure()
plot(x,y1)
plot(x,y2)
ylim([0,1])
xlim([12,30])
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
# (12.0, 30.0)

# %%
slc.CalcLeadingPerformance(outdata_list[idx],para_list[idx],ignore_timepoints=0)
# Out:
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [8.80247236]
# tot_avgdist      = 8.802472356091553
# all_finaldist    = [11.58838045]
# tot_finaldist    = 11.588380454168243
# leadRatio        = 0.0
# leadingTime      = 73.45
# finalDistToTarget= [6.64130693 5.07577083]
# leadingSuccess   = [0.94129859 0.9551361 ]
# lead_displacement = 81.25490937891375
# -----------------------------------
# -----------------------------------
# Leader i=1
# -----------
# all_avgdist      = [8.80247236]
# tot_avgdist      = 8.802472356091553
# all_finaldist    = [11.58838045]
# tot_finaldist    = 11.588380454168243
# leadRatio        = 1.0
# leadingTime      = 73.45
# finalDistToTarget= [6.64130693 5.07577083]
# leadingSuccess   = [0.94129859 0.9551361 ]
# lead_displacement = 74.59979407158622
# -----------------------------------
# Target Unit Vector: [0.70710678 0.70710678]

# %%
df=slc.ProcessParallelResults(para1name,para2name,para_list,outdata_list)
df
# Out:
# Starting type dataFrame= <class 'NoneType'>
#     leadershipRange0  leadershipRange1  leader_algstrength0  run  leadRatio0  \
# 0                0.0              16.0                  8.0    0    0.000000
# 1                0.0              16.0                  8.0    1    0.000000
# 2                0.0              16.0                 12.0    0    0.000000
# 3                0.0              16.0                 12.0    1    0.000000
# 4                0.0              16.0                 16.0    0    0.000000
# 5                0.0              16.0                 16.0    1    0.000000
# 6               12.0              16.0                  8.0    0    0.672474
# 7               12.0              16.0                  8.0    1    0.347826
# 8               12.0              16.0                 12.0    0    0.360544
# 9               12.0              16.0                 12.0    1    0.303767
# 10              12.0              16.0                 16.0    0    0.456522
# 11              12.0              16.0                 16.0    1    0.661597
# 12              24.0              16.0                  8.0    0    1.000000
# 13              24.0              16.0                  8.0    1    1.000000
# 14              24.0              16.0                 12.0    0    1.000000
# 15              24.0              16.0                 12.0    1    1.000000
# 16              24.0              16.0                 16.0    0    1.000000
# 17              24.0              16.0                 16.0    1    1.000000
# 18              36.0              16.0                  8.0    0    1.000000
# 19              36.0              16.0                  8.0    1    1.000000
# 20              36.0              16.0                 12.0    0    1.000000
# 21              36.0              16.0                 12.0    1    1.000000
# 22              36.0              16.0                 16.0    0    1.000000
# 23              36.0              16.0                 16.0    1    1.000000
# 24              48.0              16.0                  8.0    0    1.000000
# 25              48.0              16.0                  8.0    1    1.000000
# 26              48.0              16.0                 12.0    0    1.000000
# 27              48.0              16.0                 12.0    1    1.000000
# 28              48.0              16.0                 16.0    0    1.000000
# 29              48.0              16.0                 16.0    1    1.000000
# 30              60.0              16.0                  8.0    0    1.000000
# 31              60.0              16.0                  8.0    1    1.000000
# 32              60.0              16.0                 12.0    0    1.000000
# 33              60.0              16.0                 12.0    1    1.000000
# 34              60.0              16.0                 16.0    0    1.000000
# 35              60.0              16.0                 16.0    1    1.000000
# 36              72.0              16.0                  8.0    0    1.000000
# 37              72.0              16.0                  8.0    1    1.000000
# 38              72.0              16.0                 12.0    0    1.000000
# 39              72.0              16.0                 12.0    1    1.000000
# 40              72.0              16.0                 16.0    0    1.000000
# 41              72.0              16.0                 16.0    1    1.000000
#
#     leadRatio1  tot_avgdist0  tot_avgdist1  tot_finaldist0  tot_finaldist1  \
# 0     1.000000      6.852435      6.852435        7.297021        7.297021
# 1     1.000000      8.802472      8.802472       11.588380       11.588380
# 2     1.000000      4.528789      4.528789        4.301642        4.301642
# 3     1.000000      6.914111      6.914111        7.359155        7.359155
# 4     0.982670      6.306911      6.306911       10.644766       10.644766
# 5     1.000000      5.398072      5.398072        8.608610        8.608610
# 6     0.742160      8.632795      8.632795        5.361081        5.361081
# 7     0.922266     10.040220     10.040220        6.688688        6.688688
# 8     0.744898     11.295470     11.295470       14.494038       14.494038
# 9     1.000000      9.756958      9.756958        3.488746        3.488746
# 10    0.548055     13.291525     13.291525        2.881765        2.881765
# 11    0.760456      7.886496      7.886496       11.711464       11.711464
# 12    0.102439     15.910823     15.910823       12.848801       12.848801
# 13    0.108247     17.495572     17.495572       21.443476       21.443476
# 14    0.620853     11.450078     11.450078       14.854914       14.854914
# 15    0.311321     11.071862     11.071862       11.792036       11.792036
# 16    0.650718     12.001560     12.001560       15.108972       15.108972
# 17    0.115385     13.443193     13.443193       14.866453       14.866453
# 18    0.210526     13.987748     13.987748       13.383502       13.383502
# 19    0.142132     15.633629     15.633629       19.369317       19.369317
# 20    0.751244      7.021137      7.021137       12.141162       12.141162
# 21    0.200980     12.797504     12.797504       13.096393       13.096393
# 22    0.292079     12.596429     12.596429       14.370249       14.370249
# 23    0.304124     13.294463     13.294463       15.268698       15.268698
# 24    0.413146     13.783018     13.783018       15.055511       15.055511
# 25    0.119816     16.713258     16.713258       18.912944       18.912944
# 26    0.090047     15.178354     15.178354       15.551052       15.551052
# 27    0.634259     11.722621     11.722621       19.633654       19.633654
# 28    0.296651     13.361889     13.361889       16.587989       16.587989
# 29    0.459596     13.868111     13.868111       15.199503       15.199503
# 30    0.822967     12.065069     12.065069       18.550658       18.550658
# 31    0.178218     17.580903     17.580903       22.280591       22.280591
# 32    0.208531     10.556111     10.556111       10.032276       10.032276
# 33    0.361111     14.202812     14.202812       19.114193       19.114193
# 34    0.690141     10.013887     10.013887       14.123299       14.123299
# 35    0.191388     20.635042     20.635042       25.065214       25.065214
# 36    0.059091     19.482062     19.482062       18.279876       18.279876
# 37    0.490741     14.464215     14.464215       24.075667       24.075667
# 38    0.492891     11.725299     11.725299       13.570914       13.570914
# 39    1.000000     12.405148     12.405148       15.250801       15.250801
# 40    0.465686     12.002641     12.002641       16.341644       16.341644
# 41    0.771028     10.210974     10.210974        4.385963        4.385963
#
#     avg_displacement0  finalDistToTarget0  finalDistToTarget1  \
# 0           81.410821            5.243882            7.542204
# 1           77.927352            6.641307            5.075771
# 2           75.759146            5.285695            2.877009
# 3           75.117904            5.445908            1.939801
# 4           76.925328            4.846490           10.375471
# 5           68.532008            5.371297           10.219724
# 6           70.095610            7.732675            3.288905
# 7           70.543975            8.893682            8.880283
# 8           75.579452            6.261708            8.340077
# 9           72.665724            5.893173            8.833395
# 10          71.829678            6.312446            6.694936
# 11          72.933658            5.668420           10.367316
# 12          64.584383            6.855856           19.626851
# 13          63.510852            5.967143           26.945286
# 14          67.124721            4.520269           19.228985
# 15          68.153639            5.431955           16.723999
# 16          64.339076            8.710458           23.290122
# 17          65.073689            8.066041           22.071617
# 18          65.125967            8.849111           22.177898
# 19          64.121109            7.464115           25.748260
# 20          68.314218            4.941372           16.213116
# 21          67.281191            6.397771           19.097463
# 22          66.652391            5.406124           19.776337
# 23          62.771840            6.392538           21.088101
# 24          66.172511            5.566876           20.614903
# 25          64.471599            7.479665           26.001953
# 26          68.163434            4.816609           20.248870
# 27          67.770755            7.016236           24.937195
# 28          65.572240            8.764121           24.649993
# 29          64.451139            8.209301           23.166001
# 30          64.374523            8.881566           26.749558
# 31          61.457144            5.233008           27.301787
# 32          69.713364            4.817281           14.805288
# 33          63.793226            7.204762           26.018450
# 34          68.760729            5.987555           18.939851
# 35          61.769702            8.580340           33.578077
# 36          63.567720            4.326258           22.402348
# 37          67.729826            6.995780           28.044754
# 38          66.507704            4.994077           18.530722
# 39          64.845428            8.403444           22.713970
# 40          65.678235            6.040245           22.266271
# 41          69.262972            6.395838           10.065703
#
#     avg_vel2target0  avg_vel2target1  targetMovement00  targetMovement01  \
# 0          0.872864         0.832864          0.037373          0.039364
# 1          1.441267         1.392050          0.038726          0.034706
# 2          6.509100         6.572070          0.035662          0.035714
# 3          6.769938         6.390965          0.035360          0.035462
# 4          0.496031         0.415232          0.039538          0.032878
# 5          1.208402         1.152142          0.032062          0.032493
# 6          6.768391         7.214138          0.031886          0.034149
# 7          2.731259         2.653416          0.033190          0.033244
# 8          6.798894         6.695758          0.031836          0.039661
# 9          2.605326         2.391604          0.035743          0.032647
# 10         2.339205         2.305304          0.033755          0.033868
# 11         7.928474         7.366118          0.036511          0.032186
# 12         9.896031         8.109318          0.033525          0.027460
# 13         9.936171         8.637493          0.030089          0.029565
# 14         9.668517         8.215139          0.034192          0.029056
# 15         9.641101         8.417149          0.034209          0.030012
# 16         9.634743         8.231787          0.032358          0.028174
# 17         9.505096         8.473181          0.031633          0.029497
# 18         9.770690         8.498112          0.032553          0.028839
# 19         9.838756         9.043160          0.029902          0.030422
# 20         9.925267         8.905734          0.033084          0.031121
# 21         9.883821         9.009763          0.032317          0.030936
# 22         9.838815         8.995989          0.032106          0.030675
# 23         9.890087         8.530459          0.031099          0.027887
# 24         9.624089         8.089748          0.034270          0.028140
# 25         9.350905         7.657679          0.033051          0.027592
# 26         9.582210         8.625005          0.033415          0.030734
# 27         9.957105         7.703277          0.035575          0.028158
# 28         9.943021         8.464417          0.033062          0.028620
# 29         9.945790         9.185168          0.030431          0.030385
# 30         9.579625         8.339120          0.031520          0.028972
# 31         9.946286         7.181726          0.033870          0.024174
# 32         9.931296         8.825053          0.035113          0.030629
# 33         9.187217         7.575301          0.032595          0.027318
# 34         9.939518         8.072742          0.035497          0.029282
# 35         9.721791         7.718380          0.031992          0.026090
# 36         8.872232         6.874301          0.034039          0.025813
# 37         9.703822         7.330717          0.035058          0.027841
# 38         9.907266         8.063065          0.035849          0.027016
# 39         9.964765         8.893821          0.030626          0.030344
# 40         9.750784         8.691094          0.032012          0.029762
# 41         9.631363         8.915588          0.034900          0.030408
#
#     tot_time  leadingTime0  leadingTime1
# 0     121.65        121.65          -1.0
# 1      73.45         73.45          -1.0
# 2      16.10         16.10          -1.0
# 3      15.60         15.60          -1.0
# 4     213.50        213.50          -1.0
# 5      82.65         82.65          -1.0
# 6      14.35         14.35          -1.0
# 7      37.95         37.95          -1.0
# 8      14.70         14.70          -1.0
# 9      41.15         41.15          -1.0
# 10     43.70         43.70          -1.0
# 11     13.15         13.15          -1.0
# 12     10.25         10.25          -1.0
# 13      9.70          9.70          -1.0
# 14     10.55         10.55          -1.0
# 15     10.60         10.60          -1.0
# 16     10.45         10.45          -1.0
# 17     10.40         10.40          -1.0
# 18     10.45         10.45          -1.0
# 19      9.85          9.85          -1.0
# 20     10.05         10.05          -1.0
# 21     10.20         10.20          -1.0
# 22     10.10         10.10          -1.0
# 23      9.70          9.70          -1.0
# 24     10.65         10.65          -1.0
# 25     10.85         10.85          -1.0
# 26     10.55         10.55          -1.0
# 27     10.80         10.80          -1.0
# 28     10.45         10.45          -1.0
# 29      9.90          9.90          -1.0
# 30     10.45         10.45          -1.0
# 31     10.10         10.10          -1.0
# 32     10.55         10.55          -1.0
# 33     10.80         10.80          -1.0
# 34     10.65         10.65          -1.0
# 35     10.45         10.45          -1.0
# 36     11.00         11.00          -1.0
# 37     10.80         10.80          -1.0
# 38     10.55         10.55          -1.0
# 39      9.90          9.90          -1.0
# 40     10.20         10.20          -1.0
# 41     10.70         10.70          -1.0

# %%
dfgrouped_mean=df.groupby('leadershipRange0',as_index=False).mean()

# %%
plot(dfgrouped_mean.leadershipRange0,dfgrouped_mean.tot_avgdist0,'o')
plot(df.leadershipRange0,df.tot_avgdist0,'.')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
para1name="leadershipRange"
para2name="noisep"
columns=[para1name,para2name,"run","leadRatio","tot_avgdist","avg_displacement"]
df=pd.DataFrame(columns=columns)
for i in range(len(para_list)):
    print("N={},leaderRange={},run={}".format(para_list[i]['N'],
          para_list[i]['leadershipRange'],
          para_list[i]['run']))
    slc.CalcLeadingPerformance(outdata_list[i],para_list[i],ignore_timepoints=0)
    
    dataLine=dict()
    dataLine[para1name]=para_list[i][para1name]
    dataLine[para2name]=para_list[i][para2name]
    dataLine['run']=para_list[i]['run']
    dataLine['leadRatio']=np.mean(outdata_list[i]['leadRatio'])
    dataLine['tot_avgdist']=np.mean(outdata_list[i]['tot_avgdist'])
    dataLine['avg_displacement']=np.mean(outdata_list[i]['avg_displacement'])
    df=df.append(dataLine,ignore_index=True)
    
    #print(outdata_list[i]['leadRatio'])
# Out:
# N=2,leaderRange=6,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 6.02829993]
# tot_avgdist      = 6.028299925632284
# leadRatio        = 0.1727
# leadingTime      = [-1.]
# avg_displacement = 167.3031381482284
# lead_displacement = [ 168.04925172  -26.15555142]
# fish_displacement = [ 166.55702458  -28.33596352]
# -----------------------------------
# N=2,leaderRange=6,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 7.92478926]
# tot_avgdist      = 7.924789262684292
# leadRatio        = 0.0795
# leadingTime      = [ 476.5]
# avg_displacement = 214.9658979371523
# lead_displacement = [ 216.55450416    5.62977638]
# fish_displacement = [ 213.37729171    2.95139547]
# -----------------------------------
# N=2,leaderRange=6,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 7.78733634]
# tot_avgdist      = 7.7873363432172145
# leadRatio        = 0.189
# leadingTime      = [ 329.5]
# avg_displacement = 309.87045317450304
# lead_displacement = [ 311.36325686  -41.54988119]
# fish_displacement = [ 308.37764949  -40.53816005]
# -----------------------------------
# N=2,leaderRange=6,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 6.20831532]
# tot_avgdist      = 6.208315320539894
# leadRatio        = 0.2283
# leadingTime      = [ 321.85]
# avg_displacement = 317.1928603008298
# lead_displacement = [ 319.92848905   26.33288277]
# fish_displacement = [ 314.45723155   25.99932696]
# -----------------------------------
# N=2,leaderRange=6,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 6.38860231]
# tot_avgdist      = 6.388602307274236
# leadRatio        = 0.2043
# leadingTime      = [ 425.2]
# avg_displacement = 208.4471333330066
# lead_displacement = [ 208.47070308   47.4256927 ]
# fish_displacement = [ 208.42356359   51.08239121]
# -----------------------------------
# N=2,leaderRange=6,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 8.90564372]
# tot_avgdist      = 8.905643718981187
# leadRatio        = 0.2193
# leadingTime      = [ 330.85]
# avg_displacement = 312.2920235721955
# lead_displacement = [ 315.02021774  110.28883287]
# fish_displacement = [ 309.5638294   108.66676604]
# -----------------------------------
# N=2,leaderRange=6,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 5.6598172]
# tot_avgdist      = 5.659817198881896
# leadRatio        = 0.3037
# leadingTime      = [ 332.]
# avg_displacement = 257.5075830563304
# lead_displacement = [ 256.77334545   13.29401683]
# fish_displacement = [ 258.24182066   10.24907558]
# -----------------------------------
# N=2,leaderRange=6,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 4.92276839]
# tot_avgdist      = 4.922768389247554
# leadRatio        = 0.2418
# leadingTime      = [ 356.15]
# avg_displacement = 292.1215970311475
# lead_displacement = [ 294.33355403   20.8193204 ]
# fish_displacement = [ 289.90964004   23.46997708]
# -----------------------------------
# N=2,leaderRange=6,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 8.12353477]
# tot_avgdist      = 8.123534767993066
# leadRatio        = 0.2954
# leadingTime      = [ 296.2]
# avg_displacement = 319.6555386062082
# lead_displacement = [ 321.03141262  -47.42176071]
# fish_displacement = [ 318.27966459  -51.18407968]
# -----------------------------------
# N=2,leaderRange=6,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 5.79491328]
# tot_avgdist      = 5.7949132774732375
# leadRatio        = 0.2633
# leadingTime      = [ 329.05]
# avg_displacement = 321.56395259467104
# lead_displacement = [ 324.3310162    23.65693875]
# fish_displacement = [ 318.79688899   25.93304886]
# -----------------------------------
# N=2,leaderRange=6,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 8.60467721]
# tot_avgdist      = 8.60467721108055
# leadRatio        = 0.2595
# leadingTime      = [ 308.25]
# avg_displacement = 329.72936450722386
# lead_displacement = [ 331.80549288   -2.07460668]
# fish_displacement = [  3.27653236e+02  -2.57975266e-01]
# -----------------------------------
# N=2,leaderRange=6,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 4.62902374]
# tot_avgdist      = 4.629023735738653
# leadRatio        = 0.231
# leadingTime      = [ 441.7]
# avg_displacement = 241.00927198007253
# lead_displacement = [ 242.96719908   14.58926968]
# fish_displacement = [ 239.05134488   16.49985832]
# -----------------------------------
# N=2,leaderRange=6,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 8.91133455]
# tot_avgdist      = 8.911334554485817
# leadRatio        = 0.2357
# leadingTime      = [ 412.85]
# avg_displacement = 248.1464687044887
# lead_displacement = [ 249.41906213   81.92647313]
# fish_displacement = [ 246.87387528   84.51766704]
# -----------------------------------
# N=2,leaderRange=6,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 6.53919216]
# tot_avgdist      = 6.539192160210004
# leadRatio        = 0.2292
# leadingTime      = [ 320.15]
# avg_displacement = 324.8152975293091
# lead_displacement = [ 326.34556753   19.05537282]
# fish_displacement = [ 323.28502753   20.81720288]
# -----------------------------------
# N=2,leaderRange=6,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 6.70566607]
# tot_avgdist      = 6.705666074947737
# leadRatio        = 0.1824
# leadingTime      = [ 336.85]
# avg_displacement = 299.14396401360585
# lead_displacement = [ 301.14621869   14.85063666]
# fish_displacement = [ 297.14170934   10.87534139]
# -----------------------------------
# N=2,leaderRange=6,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 7.10538491]
# tot_avgdist      = 7.105384905967966
# leadRatio        = 0.278
# leadingTime      = [ 456.]
# avg_displacement = 235.3533386468402
# lead_displacement = [ 236.99357092  -76.66584021]
# fish_displacement = [ 233.71310638  -75.5210007 ]
# -----------------------------------
# N=2,leaderRange=6,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 10.53916588]
# tot_avgdist      = 10.539165884105701
# leadRatio        = 0.4566
# leadingTime      = [ 302.15]
# avg_displacement = 353.97378824868304
# lead_displacement = [ 356.81922545  -11.31801024]
# fish_displacement = [ 351.12835105  -14.41408396]
# -----------------------------------
# N=2,leaderRange=6,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 5.75375541]
# tot_avgdist      = 5.753755413112656
# leadRatio        = 0.2256
# leadingTime      = [ 458.9]
# avg_displacement = 234.6197197271332
# lead_displacement = [ 236.94339316   45.90152585]
# fish_displacement = [ 232.2960463    48.96454397]
# -----------------------------------
# N=2,leaderRange=6,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 6.92282026]
# tot_avgdist      = 6.922820256143484
# leadRatio        = 0.139
# leadingTime      = [ 416.35]
# avg_displacement = 240.34117482381168
# lead_displacement = [ 242.01725431   60.20588756]
# fish_displacement = [ 238.66509533   54.42551713]
# -----------------------------------
# N=2,leaderRange=6,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 7.55343269]
# tot_avgdist      = 7.553432693037324
# leadRatio        = 0.2511
# leadingTime      = [ 293.1]
# avg_displacement = 339.82550208296095
# lead_displacement = [ 341.46930085   22.07548055]
# fish_displacement = [ 338.18170332   24.04853317]
# -----------------------------------
# N=2,leaderRange=12,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 7.27810273]
# tot_avgdist      = 7.2781027341710525
# leadRatio        = 0.4646
# leadingTime      = [ 320.4]
# avg_displacement = 276.3535694397615
# lead_displacement = [ 276.89042573  -50.53652143]
# fish_displacement = [ 275.81671315  -47.89268756]
# -----------------------------------
# N=2,leaderRange=12,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 10.56447877]
# tot_avgdist      = 10.564478769402035
# leadRatio        = 0.3237
# leadingTime      = [ 338.]
# avg_displacement = 264.85351267987147
# lead_displacement = [ 265.5487462    15.67051269]
# fish_displacement = [ 264.15827916   12.00791909]
# -----------------------------------
# N=2,leaderRange=12,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 7.42125241]
# tot_avgdist      = 7.421252406415472
# leadRatio        = 0.385
# leadingTime      = [-1.]
# avg_displacement = 157.2657421676998
# lead_displacement = [ 161.66151754   90.15365368]
# fish_displacement = [ 152.8699668    81.68616239]
# -----------------------------------
# N=2,leaderRange=12,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 12.0098917]
# tot_avgdist      = 12.009891702798065
# leadRatio        = 0.4428
# leadingTime      = [ 255.65]
# avg_displacement = 357.908850021385
# lead_displacement = [ 360.67673712   -9.98901307]
# fish_displacement = [ 355.14096292   -6.91561342]
# -----------------------------------
# N=2,leaderRange=12,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 6.78714911]
# tot_avgdist      = 6.7871491068830405
# leadRatio        = 0.4434
# leadingTime      = [ 364.1]
# avg_displacement = 295.96944132995213
# lead_displacement = [ 299.09360688  -40.822086  ]
# fish_displacement = [ 292.84527578  -47.11620971]
# -----------------------------------
# N=2,leaderRange=12,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 11.85064585]
# tot_avgdist      = 11.850645853852003
# leadRatio        = 0.42
# leadingTime      = [ 296.55]
# avg_displacement = 322.2942442513745
# lead_displacement = [ 323.95937029   34.44608579]
# fish_displacement = [ 320.62911821   36.4777356 ]
# -----------------------------------
# N=2,leaderRange=12,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 8.22301298]
# tot_avgdist      = 8.223012984643322
# leadRatio        = 0.4741
# leadingTime      = [ 323.15]
# avg_displacement = 292.90235289067215
# lead_displacement = [ 294.67249551  -22.54101011]
# fish_displacement = [ 291.13221028  -20.60120053]
# -----------------------------------
# N=2,leaderRange=12,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 7.71446144]
# tot_avgdist      = 7.714461442108477
# leadRatio        = 0.4225
# leadingTime      = [ 468.9]
# avg_displacement = 220.67244941818345
# lead_displacement = [ 221.94942564  -22.01841547]
# fish_displacement = [ 219.39547319  -18.3318677 ]
# -----------------------------------
# N=2,leaderRange=12,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 6.52149073]
# tot_avgdist      = 6.5214907309276935
# leadRatio        = 0.3187
# leadingTime      = [ 484.2]
# avg_displacement = 214.01180966289616
# lead_displacement = [ 216.29076859   42.54296788]
# fish_displacement = [ 211.73285074   39.08866831]
# -----------------------------------
# N=2,leaderRange=12,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 5.93607015]
# tot_avgdist      = 5.936070151996092
# leadRatio        = 0.3351
# leadingTime      = [ 372.25]
# avg_displacement = 233.05232640130123
# lead_displacement = [ 231.89932597   81.55630415]
# fish_displacement = [ 234.20532684   78.01329659]
# -----------------------------------
# N=2,leaderRange=12,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 7.20931522]
# tot_avgdist      = 7.2093152242056995
# leadRatio        = 0.3869
# leadingTime      = [ 401.35]
# avg_displacement = 240.3440513775349
# lead_displacement = [ 241.31052773  -51.48973333]
# fish_displacement = [ 239.37757503  -47.99619553]
# -----------------------------------
# N=2,leaderRange=12,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 14.46187057]
# tot_avgdist      = 14.461870571947188
# leadRatio        = 0.2764
# leadingTime      = [ 366.2]
# avg_displacement = 258.83283955922707
# lead_displacement = [ 259.6289283    73.98562425]
# fish_displacement = [ 258.03675082   71.90459547]
# -----------------------------------
# N=2,leaderRange=12,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 8.44967147]
# tot_avgdist      = 8.4496714666038
# leadRatio        = 0.4681
# leadingTime      = [ 306.45]
# avg_displacement = 292.9185981015553
# lead_displacement = [ 294.29944284  -91.6971979 ]
# fish_displacement = [ 291.53775337  -88.91095974]
# -----------------------------------
# N=2,leaderRange=12,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 8.72843342]
# tot_avgdist      = 8.728433418003744
# leadRatio        = 0.4038
# leadingTime      = [ 265.]
# avg_displacement = 344.5773327084744
# lead_displacement = [ 346.5527503    17.76536846]
# fish_displacement = [ 342.60191512   19.50561986]
# -----------------------------------
# N=2,leaderRange=12,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 10.26257701]
# tot_avgdist      = 10.262577012756463
# leadRatio        = 0.4593
# leadingTime      = [ 307.75]
# avg_displacement = 299.1550257684703
# lead_displacement = [ 303.17251536   -7.87554751]
# fish_displacement = [ 295.13753618  -19.45232375]
# -----------------------------------
# N=2,leaderRange=12,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 11.13991254]
# tot_avgdist      = 11.139912539606874
# leadRatio        = 0.2821
# leadingTime      = [ 353.85]
# avg_displacement = 254.8638157718797
# lead_displacement = [ 256.23381093  -37.29778773]
# fish_displacement = [ 253.49382061  -39.48297407]
# -----------------------------------
# N=2,leaderRange=12,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 6.72412628]
# tot_avgdist      = 6.724126277029319
# leadRatio        = 0.4758
# leadingTime      = [ 303.6]
# avg_displacement = 309.9861308474555
# lead_displacement = [ 311.75753649   48.39227207]
# fish_displacement = [ 308.21472521   45.18944009]
# -----------------------------------
# N=2,leaderRange=12,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 6.15880723]
# tot_avgdist      = 6.158807228431944
# leadRatio        = 0.3091
# leadingTime      = [ 319.]
# avg_displacement = 276.2050661223069
# lead_displacement = [ 275.91807617  -17.24022525]
# fish_displacement = [ 276.49205607  -20.80098539]
# -----------------------------------
# N=2,leaderRange=12,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 10.20809092]
# tot_avgdist      = 10.208090924848102
# leadRatio        = 0.5658
# leadingTime      = [ 308.2]
# avg_displacement = 319.9712434629937
# lead_displacement = [ 325.36869575   36.15808973]
# fish_displacement = [ 314.57379118   27.52507721]
# -----------------------------------
# N=2,leaderRange=12,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 13.764492]
# tot_avgdist      = 13.764491995526807
# leadRatio        = 0.4498
# leadingTime      = [ 249.75]
# avg_displacement = 302.1965044970376
# lead_displacement = [ 302.2971687   108.70690608]
# fish_displacement = [ 302.09584029  104.95647088]
# -----------------------------------
# N=2,leaderRange=18,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 12.96469418]
# tot_avgdist      = 12.964694177556828
# leadRatio        = 0.6055
# leadingTime      = [ 313.6]
# avg_displacement = 313.87300119897543
# lead_displacement = [ 319.26715812   66.85164001]
# fish_displacement = [ 308.47884427   59.89282237]
# -----------------------------------
# N=2,leaderRange=18,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 12.10985969]
# tot_avgdist      = 12.109859690195671
# leadRatio        = 0.4976
# leadingTime      = [ 275.8]
# avg_displacement = 305.510277170702
# lead_displacement = [ 306.52975368   -1.49381961]
# fish_displacement = [ 304.49080066   -3.53399009]
# -----------------------------------
# N=2,leaderRange=18,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 9.63558582]
# tot_avgdist      = 9.635585824512795
# leadRatio        = 0.5595
# leadingTime      = [ 306.2]
# avg_displacement = 313.4723735747718
# lead_displacement = [ 316.88756415   54.67402017]
# fish_displacement = [ 310.057183     50.40962081]
# -----------------------------------
# N=2,leaderRange=18,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 16.65249696]
# tot_avgdist      = 16.65249696271583
# leadRatio        = 0.515
# leadingTime      = [ 278.15]
# avg_displacement = 332.87735827572874
# lead_displacement = [ 336.13877459  -19.18267957]
# fish_displacement = [ 329.61594196  -18.72140344]
# -----------------------------------
# N=2,leaderRange=18,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 11.83618399]
# tot_avgdist      = 11.836183990023407
# leadRatio        = 0.4451
# leadingTime      = [ 378.95]
# avg_displacement = 225.10738992627356
# lead_displacement = [ 227.98814242   60.1074172 ]
# fish_displacement = [ 222.22663743   56.14093966]
# -----------------------------------
# N=2,leaderRange=18,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 15.04657974]
# tot_avgdist      = 15.046579738833552
# leadRatio        = 0.6133
# leadingTime      = [ 318.8]
# avg_displacement = 327.22761065148666
# lead_displacement = [ 333.17673098   -2.15899614]
# fish_displacement = [  3.21278490e+02   1.20986499e-01]
# -----------------------------------
# N=2,leaderRange=18,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 7.99936293]
# tot_avgdist      = 7.999362930353506
# leadRatio        = 0.509
# leadingTime      = [ 320.85]
# avg_displacement = 295.41038263936707
# lead_displacement = [ 300.2616039    49.76533136]
# fish_displacement = [ 290.55916138   42.09482119]
# -----------------------------------
# N=2,leaderRange=18,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 14.01246995]
# tot_avgdist      = 14.012469949442456
# leadRatio        = 0.5467
# leadingTime      = [ 257.6]
# avg_displacement = 314.2451794321928
# lead_displacement = [ 320.92051275    0.82065475]
# fish_displacement = [ 307.56984611    2.2225112 ]
# -----------------------------------
# N=2,leaderRange=18,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 16.829219]
# tot_avgdist      = 16.829219001263613
# leadRatio        = 0.5006
# leadingTime      = [ 358.75]
# avg_displacement = 262.73035019715473
# lead_displacement = [ 264.55876806  -54.80659252]
# fish_displacement = [ 260.90193234  -52.12317999]
# -----------------------------------
# N=2,leaderRange=18,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 8.10307721]
# tot_avgdist      = 8.103077206000204
# leadRatio        = 0.5025
# leadingTime      = [ 344.05]
# avg_displacement = 294.00629817941456
# lead_displacement = [ 295.78709379  -55.20547286]
# fish_displacement = [ 292.22550257  -53.63016838]
# -----------------------------------
# N=2,leaderRange=18,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 7.66259765]
# tot_avgdist      = 7.662597647108857
# leadRatio        = 0.3951
# leadingTime      = [ 384.5]
# avg_displacement = 240.04043371294648
# lead_displacement = [ 241.62558333  -21.33900049]
# fish_displacement = [ 238.4552841   -28.48577311]
# -----------------------------------
# N=2,leaderRange=18,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 16.12791205]
# tot_avgdist      = 16.12791205344744
# leadRatio        = 0.5518
# leadingTime      = [ 311.15]
# avg_displacement = 289.2915729227649
# lead_displacement = [ 291.26901107  -58.24067786]
# fish_displacement = [ 287.31413477  -58.48796956]
# -----------------------------------
# N=2,leaderRange=18,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 7.41347552]
# tot_avgdist      = 7.413475521144734
# leadRatio        = 0.5579
# leadingTime      = [ 324.15]
# avg_displacement = 296.5596482795926
# lead_displacement = [ 299.3467972    37.80712162]
# fish_displacement = [ 293.77249936   31.75606471]
# -----------------------------------
# N=2,leaderRange=18,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 8.54582085]
# tot_avgdist      = 8.545820851324715
# leadRatio        = 0.3828
# leadingTime      = [ 362.45]
# avg_displacement = 277.4505038353491
# lead_displacement = [ 279.23827842    6.15985997]
# fish_displacement = [ 275.66272925    9.18678571]
# -----------------------------------
# N=2,leaderRange=18,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 7.05711964]
# tot_avgdist      = 7.057119639150551
# leadRatio        = 0.513
# leadingTime      = [ 332.]
# avg_displacement = 291.77288831978746
# lead_displacement = [ 294.531017     39.32840725]
# fish_displacement = [ 289.01475964   35.76306475]
# -----------------------------------
# N=2,leaderRange=18,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 17.0758208]
# tot_avgdist      = 17.07582079748539
# leadRatio        = 0.6554
# leadingTime      = [ 308.75]
# avg_displacement = 317.58783581964866
# lead_displacement = [ 324.64441041    7.25179965]
# fish_displacement = [ 310.53126123    8.73097476]
# -----------------------------------
# N=2,leaderRange=18,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 9.82238249]
# tot_avgdist      = 9.822382490913487
# leadRatio        = 0.5301
# leadingTime      = [ 317.2]
# avg_displacement = 284.4638003647251
# lead_displacement = [ 286.00001981   12.21251024]
# fish_displacement = [ 282.92758092    7.68157526]
# -----------------------------------
# N=2,leaderRange=18,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 16.09204302]
# tot_avgdist      = 16.09204301895086
# leadRatio        = 0.5689
# leadingTime      = [ 318.55]
# avg_displacement = 318.5925115909805
# lead_displacement = [ 320.92951468  -29.43249957]
# fish_displacement = [ 316.2555085   -28.53415081]
# -----------------------------------
# N=2,leaderRange=18,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 7.32036247]
# tot_avgdist      = 7.320362474363409
# leadRatio        = 0.5145
# leadingTime      = [ 326.8]
# avg_displacement = 295.71214317308295
# lead_displacement = [ 298.6045232    34.75251549]
# fish_displacement = [ 292.81976315   29.62118004]
# -----------------------------------
# N=2,leaderRange=18,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 12.04279169]
# tot_avgdist      = 12.042791693646478
# leadRatio        = 0.4638
# leadingTime      = [ 340.3]
# avg_displacement = 284.73717415499675
# lead_displacement = [ 288.2500618   -93.69342102]
# fish_displacement = [ 281.22428651  -90.12191763]
# -----------------------------------
# N=2,leaderRange=24,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 18.82213395]
# tot_avgdist      = 18.8221339520135
# leadRatio        = 0.5965
# leadingTime      = [ 386.35]
# avg_displacement = 299.0338008340748
# lead_displacement = [ 309.72431638   90.44765003]
# fish_displacement = [ 288.34328529   77.56947959]
# -----------------------------------
# N=2,leaderRange=24,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 19.9350635]
# tot_avgdist      = 19.93506350090329
# leadRatio        = 0.5218
# leadingTime      = [ 292.15]
# avg_displacement = 295.3581566432629
# lead_displacement = [ 296.88794127  -67.98839852]
# fish_displacement = [ 293.82837201  -66.26732921]
# -----------------------------------
# N=2,leaderRange=24,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 12.88909631]
# tot_avgdist      = 12.889096308020752
# leadRatio        = 0.54
# leadingTime      = [ 340.3]
# avg_displacement = 301.11639007937197
# lead_displacement = [ 303.37586881  -64.17436112]
# fish_displacement = [ 298.85691135  -61.7068894 ]
# -----------------------------------
# N=2,leaderRange=24,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 16.77602485]
# tot_avgdist      = 16.776024854148748
# leadRatio        = 0.3818
# leadingTime      = [ 355.05]
# avg_displacement = 238.7889413050284
# lead_displacement = [ 239.9663812    -2.69631681]
# fish_displacement = [ 237.61150141   -1.9992824 ]
# -----------------------------------
# N=2,leaderRange=24,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 13.22107628]
# tot_avgdist      = 13.221076279014275
# leadRatio        = 0.6324
# leadingTime      = [ 292.4]
# avg_displacement = 321.5327506414874
# lead_displacement = [ 323.70620746   56.27511709]
# fish_displacement = [ 319.35929382   52.36518967]
# -----------------------------------
# N=2,leaderRange=24,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 19.69439318]
# tot_avgdist      = 19.694393179706466
# leadRatio        = 0.4358
# leadingTime      = [ 426.1]
# avg_displacement = 242.61950054137003
# lead_displacement = [ 244.52849869  -84.59280408]
# fish_displacement = [ 240.71050239  -83.48196816]
# -----------------------------------
# N=2,leaderRange=24,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 19.4730079]
# tot_avgdist      = 19.47300789731876
# leadRatio        = 0.7168
# leadingTime      = [ 314.6]
# avg_displacement = 328.65589999269076
# lead_displacement = [ 331.25334423  -25.56193168]
# fish_displacement = [ 326.05845576  -31.38032557]
# -----------------------------------
# N=2,leaderRange=24,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 8.77696892]
# tot_avgdist      = 8.776968922478225
# leadRatio        = 0.305
# leadingTime      = [ 350.65]
# avg_displacement = 253.20424000450512
# lead_displacement = [ 253.47191786 -104.32767218]
# fish_displacement = [ 252.93656215 -100.99072515]
# -----------------------------------
# N=2,leaderRange=24,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 19.77993557]
# tot_avgdist      = 19.77993557113656
# leadRatio        = 0.5244
# leadingTime      = [ 362.65]
# avg_displacement = 285.0706040252612
# lead_displacement = [ 285.89166705  -57.06399238]
# fish_displacement = [ 284.249541    -54.27998448]
# -----------------------------------
# N=2,leaderRange=24,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 19.21750674]
# tot_avgdist      = 19.21750673596368
# leadRatio        = 0.5623
# leadingTime      = [ 267.65]
# avg_displacement = 341.2603810646897
# lead_displacement = [ 342.6996455    51.33726765]
# fish_displacement = [ 339.82111663   50.81793307]
# -----------------------------------
# N=2,leaderRange=24,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 21.09956172]
# tot_avgdist      = 21.0995617232605
# leadRatio        = 0.573
# leadingTime      = [ 301.4]
# avg_displacement = 332.9730521894786
# lead_displacement = [ 334.29296533   -9.92669544]
# fish_displacement = [ 331.65313905   -9.00902966]
# -----------------------------------
# N=2,leaderRange=24,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 15.56747654]
# tot_avgdist      = 15.567476542738397
# leadRatio        = 0.4598
# leadingTime      = [ 337.4]
# avg_displacement = 322.5107453496204
# lead_displacement = [ 323.90887976  -29.50900556]
# fish_displacement = [ 321.11261094  -28.04203912]
# -----------------------------------
# N=2,leaderRange=24,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 18.77404758]
# tot_avgdist      = 18.77404758186801
# leadRatio        = 0.5566
# leadingTime      = [ 280.]
# avg_displacement = 347.9356934837389
# lead_displacement = [ 351.1638057    -3.96128295]
# fish_displacement = [ 344.70758126    0.70143319]
# -----------------------------------
# N=2,leaderRange=24,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 15.56260346]
# tot_avgdist      = 15.562603460948768
# leadRatio        = 0.508
# leadingTime      = [ 358.9]
# avg_displacement = 258.1502526626257
# lead_displacement = [ 258.1152103    19.41520103]
# fish_displacement = [ 258.18529502   19.25198073]
# -----------------------------------
# N=2,leaderRange=24,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 27.3674993]
# tot_avgdist      = 27.36749930007252
# leadRatio        = 0.5235
# leadingTime      = [ 342.15]
# avg_displacement = 321.0873782389515
# lead_displacement = [ 324.49633321  -27.37647298]
# fish_displacement = [ 317.67842326  -24.81594177]
# -----------------------------------
# N=2,leaderRange=24,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 16.79220113]
# tot_avgdist      = 16.7922011317233
# leadRatio        = 0.59
# leadingTime      = [ 321.5]
# avg_displacement = 282.5355152501819
# lead_displacement = [ 287.62027589   12.11788352]
# fish_displacement = [ 277.45075461    1.92511477]
# -----------------------------------
# N=2,leaderRange=24,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 17.60565056]
# tot_avgdist      = 17.605650556313826
# leadRatio        = 0.4272
# leadingTime      = [ 456.05]
# avg_displacement = 217.73605136023286
# lead_displacement = [ 219.5912878    22.17808096]
# fish_displacement = [ 215.88081492   26.14431542]
# -----------------------------------
# N=2,leaderRange=24,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 41.02046655]
# tot_avgdist      = 41.020466549784594
# leadRatio        = 0.4341
# leadingTime      = [ 454.8]
# avg_displacement = 191.60637394786255
# lead_displacement = [ 193.9004527   -54.04690754]
# fish_displacement = [ 189.3122952   -57.89090566]
# -----------------------------------
# N=2,leaderRange=24,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 22.51769433]
# tot_avgdist      = 22.517694332080556
# leadRatio        = 0.4727
# leadingTime      = [ 399.15]
# avg_displacement = 277.52907626159157
# lead_displacement = [ 279.5843268   -70.36689714]
# fish_displacement = [ 275.47382572  -69.82540923]
# -----------------------------------
# N=2,leaderRange=24,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 25.40848593]
# tot_avgdist      = 25.408485931849263
# leadRatio        = 0.4702
# leadingTime      = [ 358.1]
# avg_displacement = 263.6813423142718
# lead_displacement = [ 266.33258096    6.19290926]
# fish_displacement = [ 261.03010367    1.46877129]
# -----------------------------------
# N=2,leaderRange=30,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 20.3224723]
# tot_avgdist      = 20.3224722954783
# leadRatio        = 0.4237
# leadingTime      = [ 452.45]
# avg_displacement = 238.01344560539872
# lead_displacement = [ 248.92817716   27.87817546]
# fish_displacement = [ 227.09871405   34.71843851]
# -----------------------------------
# N=2,leaderRange=30,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 27.22998781]
# tot_avgdist      = 27.22998781320881
# leadRatio        = 0.5829
# leadingTime      = [ 379.8]
# avg_displacement = 260.97737365399416
# lead_displacement = [ 267.40259598  -15.81968054]
# fish_displacement = [ 254.55215133  -25.57074012]
# -----------------------------------
# N=2,leaderRange=30,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 22.5482733]
# tot_avgdist      = 22.54827329860898
# leadRatio        = 0.5566
# leadingTime      = [ 400.85]
# avg_displacement = 268.3522441001258
# lead_displacement = [ 271.41237062  -11.52103271]
# fish_displacement = [ 265.29211758   -8.17384453]
# -----------------------------------
# N=2,leaderRange=30,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 20.13382408]
# tot_avgdist      = 20.133824075888498
# leadRatio        = 0.4403
# leadingTime      = [ 412.75]
# avg_displacement = 211.70142174427485
# lead_displacement = [ 212.91898435  -73.31757574]
# fish_displacement = [ 210.48385914  -74.04460221]
# -----------------------------------
# N=2,leaderRange=30,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 18.03814935]
# tot_avgdist      = 18.03814935321086
# leadRatio        = 0.4654
# leadingTime      = [ 460.65]
# avg_displacement = 224.15763985397183
# lead_displacement = [ 237.22651011  -21.09510151]
# fish_displacement = [ 211.0887696   -14.57207597]
# -----------------------------------
# N=2,leaderRange=30,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 20.8991971]
# tot_avgdist      = 20.89919709861157
# leadRatio        = 0.6211
# leadingTime      = [ 332.05]
# avg_displacement = 290.9392362382777
# lead_displacement = [ 302.00178754    6.99735604]
# fish_displacement = [ 279.87668494   -1.27496541]
# -----------------------------------
# N=2,leaderRange=30,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 15.23366687]
# tot_avgdist      = 15.233666872964177
# leadRatio        = 0.5527
# leadingTime      = [ 397.25]
# avg_displacement = 291.9459673663248
# lead_displacement = [ 303.74908114   -4.37355701]
# fish_displacement = [ 280.14285359    5.01888501]
# -----------------------------------
# N=2,leaderRange=30,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 25.76678426]
# tot_avgdist      = 25.76678425828504
# leadRatio        = 0.5522
# leadingTime      = [ 360.85]
# avg_displacement = 250.43659740902
# lead_displacement = [ 251.3692942   -14.68696132]
# fish_displacement = [ 249.50390062  -18.89247971]
# -----------------------------------
# N=2,leaderRange=30,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 25.00170619]
# tot_avgdist      = 25.001706187425558
# leadRatio        = 0.5471
# leadingTime      = [ 430.85]
# avg_displacement = 254.19868923058044
# lead_displacement = [ 268.68642024  -12.42190792]
# fish_displacement = [ 239.71095822   -4.86774609]
# -----------------------------------
# N=2,leaderRange=30,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 29.97318204]
# tot_avgdist      = 29.973182042543012
# leadRatio        = 0.4449
# leadingTime      = [ 415.85]
# avg_displacement = 215.57909206137418
# lead_displacement = [ 216.75591568  -79.34320639]
# fish_displacement = [ 214.40226844  -76.58874239]
# -----------------------------------
# N=2,leaderRange=30,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 19.26016759]
# tot_avgdist      = 19.260167589151727
# leadRatio        = 0.4663
# leadingTime      = [ 483.75]
# avg_displacement = 208.97605808928728
# lead_displacement = [ 217.9227819   -30.81038634]
# fish_displacement = [ 200.02933428  -27.58158097]
# -----------------------------------
# N=2,leaderRange=30,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 31.27859898]
# tot_avgdist      = 31.27859897556167
# leadRatio        = 0.6454
# leadingTime      = [ 320.1]
# avg_displacement = 305.4210090821156
# lead_displacement = [ 321.25802714   -1.21910304]
# fish_displacement = [ 289.58399102  -13.18320587]
# -----------------------------------
# N=2,leaderRange=30,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 14.2787338]
# tot_avgdist      = 14.278733802520659
# leadRatio        = 0.5639
# leadingTime      = [ 467.6]
# avg_displacement = 218.12656639424668
# lead_displacement = [ 232.77437862  -43.29394794]
# fish_displacement = [ 203.47875417  -31.95705453]
# -----------------------------------
# N=2,leaderRange=30,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 29.34575125]
# tot_avgdist      = 29.34575125148921
# leadRatio        = 0.6621
# leadingTime      = [ 333.7]
# avg_displacement = 296.6096019633972
# lead_displacement = [ 298.47104879  -34.68301708]
# fish_displacement = [ 294.74815514  -30.3040641 ]
# -----------------------------------
# N=2,leaderRange=30,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 15.89802359]
# tot_avgdist      = 15.89802358500542
# leadRatio        = 0.5253
# leadingTime      = [ 466.1]
# avg_displacement = 211.41646539123735
# lead_displacement = [ 216.5537903   -60.99452389]
# fish_displacement = [ 206.27914048  -56.97390462]
# -----------------------------------
# N=2,leaderRange=30,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 29.78400297]
# tot_avgdist      = 29.784002970595576
# leadRatio        = 0.4795
# leadingTime      = [ 379.2]
# avg_displacement = 240.88135558397994
# lead_displacement = [ 242.86414438  -62.99830342]
# fish_displacement = [ 238.89856678  -60.64507892]
# -----------------------------------
# N=2,leaderRange=30,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 21.0836426]
# tot_avgdist      = 21.083642597061527
# leadRatio        = 0.5589
# leadingTime      = [ 403.8]
# avg_displacement = 284.2675352794825
# lead_displacement = [ 297.2357785   -36.67271984]
# fish_displacement = [ 271.29929206  -29.69579255]
# -----------------------------------
# N=2,leaderRange=30,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 22.75007983]
# tot_avgdist      = 22.750079833495736
# leadRatio        = 0.6324
# leadingTime      = [ 301.05]
# avg_displacement = 298.8571807774658
# lead_displacement = [ 314.65729678  -57.13313099]
# fish_displacement = [ 283.05706478  -37.83491784]
# -----------------------------------
# N=2,leaderRange=30,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 26.39477819]
# tot_avgdist      = 26.394778192699828
# leadRatio        = 0.6114
# leadingTime      = [ 294.25]
# avg_displacement = 339.21506054515726
# lead_displacement = [ 353.28844726  -37.84493005]
# fish_displacement = [ 325.14167383  -29.91793194]
# -----------------------------------
# N=2,leaderRange=30,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 25.43927978]
# tot_avgdist      = 25.43927977549298
# leadRatio        = 0.4407
# leadingTime      = [ 357.35]
# avg_displacement = 233.48039046898947
# lead_displacement = [ 247.96901647  -25.09388752]
# fish_displacement = [ 218.99176447   -9.61047998]
# -----------------------------------
# N=2,leaderRange=36,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 21.32642699]
# tot_avgdist      = 21.326426987240165
# leadRatio        = 0.6359
# leadingTime      = [ 418.5]
# avg_displacement = 265.58179846690626
# lead_displacement = [ 281.68429907   -9.21446585]
# fish_displacement = [ 249.47929787    2.09381713]
# -----------------------------------
# N=2,leaderRange=36,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 34.14178776]
# tot_avgdist      = 34.14178775757917
# leadRatio        = 0.5313
# leadingTime      = [ 355.75]
# avg_displacement = 238.17857864514752
# lead_displacement = [ 254.99486446   -8.69601558]
# fish_displacement = [ 221.36229283   -0.47711928]
# -----------------------------------
# N=2,leaderRange=36,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 23.10532323]
# tot_avgdist      = 23.105323231076838
# leadRatio        = 0.5042
# leadingTime      = [ 423.1]
# avg_displacement = 262.1994919143679
# lead_displacement = [ 278.05015978   32.87357736]
# fish_displacement = [ 246.34882405   42.86426658]
# -----------------------------------
# N=2,leaderRange=36,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 37.59403228]
# tot_avgdist      = 37.5940322812832
# leadRatio        = 0.518
# leadingTime      = [ 394.7]
# avg_displacement = 234.20274626175106
# lead_displacement = [ 235.78239546  -42.78889667]
# fish_displacement = [ 232.62309706  -41.2066076 ]
# -----------------------------------
# N=2,leaderRange=36,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 15.95378177]
# tot_avgdist      = 15.953781774585371
# leadRatio        = 0.5023
# leadingTime      = [ 441.35]
# avg_displacement = 251.11228773454218
# lead_displacement = [ 259.70207416   34.40445924]
# fish_displacement = [ 242.52250131   36.88007791]
# -----------------------------------
# N=2,leaderRange=36,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 17.27108435]
# tot_avgdist      = 17.271084353698615
# leadRatio        = 0.6045
# leadingTime      = [ 386.1]
# avg_displacement = 249.7891733015449
# lead_displacement = [ 267.73347551  -64.16753168]
# fish_displacement = [ 231.8448711  -65.9119942]
# -----------------------------------
# N=2,leaderRange=36,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 20.04121426]
# tot_avgdist      = 20.041214260792774
# leadRatio        = 0.5383
# leadingTime      = [ 399.45]
# avg_displacement = 282.1166768249916
# lead_displacement = [ 295.62627246   26.33876174]
# fish_displacement = [ 268.60708119   37.40341315]
# -----------------------------------
# N=2,leaderRange=36,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 17.1271412]
# tot_avgdist      = 17.127141196100915
# leadRatio        = 0.5673
# leadingTime      = [ 346.85]
# avg_displacement = 271.1602398272389
# lead_displacement = [ 283.01596843  -22.9937788 ]
# fish_displacement = [ 259.30451122   -7.21407032]
# -----------------------------------
# N=2,leaderRange=36,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 17.69242655]
# tot_avgdist      = 17.692426551324676
# leadRatio        = 0.5208
# leadingTime      = [ 411.85]
# avg_displacement = 262.85091839822053
# lead_displacement = [ 271.57779483   10.38460431]
# fish_displacement = [ 254.12404197   10.94605618]
# -----------------------------------
# N=2,leaderRange=36,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 37.61950005]
# tot_avgdist      = 37.619500054821245
# leadRatio        = 0.5334
# leadingTime      = [ 389.4]
# avg_displacement = 243.21550109173853
# lead_displacement = [ 245.01469954  -29.15053537]
# fish_displacement = [ 241.41630264  -27.49649554]
# -----------------------------------
# N=2,leaderRange=36,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 26.80813686]
# tot_avgdist      = 26.808136855332613
# leadRatio        = 0.5321
# leadingTime      = [ 426.05]
# avg_displacement = 249.2902238475662
# lead_displacement = [ 256.01157646   29.08525681]
# fish_displacement = [ 242.56887124   39.10724866]
# -----------------------------------
# N=2,leaderRange=36,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 19.36165702]
# tot_avgdist      = 19.36165702028875
# leadRatio        = 0.6304
# leadingTime      = [ 335.75]
# avg_displacement = 274.9318330405529
# lead_displacement = [ 276.50334866  -34.01592509]
# fish_displacement = [ 273.36031743  -37.03613503]
# -----------------------------------
# N=2,leaderRange=36,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 22.45968696]
# tot_avgdist      = 22.459686957197448
# leadRatio        = 0.4607
# leadingTime      = [ 421.1]
# avg_displacement = 251.89574489628933
# lead_displacement = [ 259.39488879   38.37309502]
# fish_displacement = [ 244.396601     50.75741582]
# -----------------------------------
# N=2,leaderRange=36,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 18.63608505]
# tot_avgdist      = 18.63608504609245
# leadRatio        = 0.6157
# leadingTime      = [ 381.75]
# avg_displacement = 258.92614141137847
# lead_displacement = [ 274.97835255    7.94503268]
# fish_displacement = [ 242.87393027   23.77352586]
# -----------------------------------
# N=2,leaderRange=36,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 21.42188728]
# tot_avgdist      = 21.42188728054261
# leadRatio        = 0.4576
# leadingTime      = [ 485.65]
# avg_displacement = 191.2751137717347
# lead_displacement = [ 197.81393525   41.00062923]
# fish_displacement = [ 184.73629229   50.07828866]
# -----------------------------------
# N=2,leaderRange=36,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 32.88271546]
# tot_avgdist      = 32.88271546313496
# leadRatio        = 0.4977
# leadingTime      = [ 458.6]
# avg_displacement = 182.43619772119652
# lead_displacement = [ 198.4199818   -2.8718943]
# fish_displacement = [ 166.45241364    8.75033795]
# -----------------------------------
# N=2,leaderRange=36,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 25.18231824]
# tot_avgdist      = 25.18231823837509
# leadRatio        = 0.6755
# leadingTime      = [ 280.05]
# avg_displacement = 357.0765039487803
# lead_displacement = [ 372.09983196  -22.41702039]
# fish_displacement = [ 342.05317594  -12.93068987]
# -----------------------------------
# N=2,leaderRange=36,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 22.59896816]
# tot_avgdist      = 22.598968157025137
# leadRatio        = 0.6416
# leadingTime      = [ 344.45]
# avg_displacement = 265.1370055217219
# lead_displacement = [ 267.06288754  -35.01510774]
# fish_displacement = [ 263.2111235   -35.91354453]
# -----------------------------------
# N=2,leaderRange=36,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 34.12151977]
# tot_avgdist      = 34.121519774317264
# leadRatio        = 0.3398
# leadingTime      = [-1.]
# avg_displacement = 62.02593701657501
# lead_displacement = [ 64.17844449   8.96220149]
# fish_displacement = [ 59.87342954  13.22813676]
# -----------------------------------
# N=2,leaderRange=36,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 31.16440943]
# tot_avgdist      = 31.164409429824076
# leadRatio        = 0.4907
# leadingTime      = [ 405.9]
# avg_displacement = 228.7974640672295
# lead_displacement = [ 230.44328541  -31.52395653]
# fish_displacement = [ 227.15164272  -29.50134227]
# -----------------------------------
# N=2,leaderRange=42,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 22.17347462]
# tot_avgdist      = 22.173474617361865
# leadRatio        = 0.5646
# leadingTime      = [ 418.25]
# avg_displacement = 267.6966165808783
# lead_displacement = [ 281.08473007    4.50613492]
# fish_displacement = [ 254.30850309   11.97938113]
# -----------------------------------
# N=2,leaderRange=42,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 40.70311691]
# tot_avgdist      = 40.70311691471922
# leadRatio        = 0.527
# leadingTime      = [-1.]
# avg_displacement = 178.95502159325687
# lead_displacement = [ 193.66370278  -55.86383565]
# fish_displacement = [ 164.24634041  -56.27437541]
# -----------------------------------
# N=2,leaderRange=42,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 19.69220186]
# tot_avgdist      = 19.6922018565642
# leadRatio        = 0.5686
# leadingTime      = [ 461.2]
# avg_displacement = 227.2731435049798
# lead_displacement = [ 238.75655401   11.46361129]
# fish_displacement = [ 215.789733     16.77599566]
# -----------------------------------
# N=2,leaderRange=42,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 23.16729438]
# tot_avgdist      = 23.167294376062614
# leadRatio        = 0.6396
# leadingTime      = [ 363.45]
# avg_displacement = 247.34681869445228
# lead_displacement = [ 248.83991657  -52.47742233]
# fish_displacement = [ 245.85372082  -51.49284566]
# -----------------------------------
# N=2,leaderRange=42,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 21.37023372]
# tot_avgdist      = 21.37023371897067
# leadRatio        = 0.5394
# leadingTime      = [ 483.]
# avg_displacement = 208.10542785294174
# lead_displacement = [ 216.93104758    2.41899141]
# fish_displacement = [ 199.27980812    5.23943816]
# -----------------------------------
# N=2,leaderRange=42,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 21.51454301]
# tot_avgdist      = 21.514543013744678
# leadRatio        = 0.5399
# ...
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 31.72203243]
# tot_avgdist      = 31.722032428037163
# leadRatio        = 0.4522
# leadingTime      = [ 436.05]
# avg_displacement = 175.66383892699338
# lead_displacement = [ 177.34204601  -72.86690107]
# fish_displacement = [ 173.98563184  -69.67774953]
# -----------------------------------
# N=2,leaderRange=48,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 31.33087208]
# tot_avgdist      = 31.330872075879252
# leadRatio        = 0.5207
# leadingTime      = [ 275.]
# avg_displacement = 176.71809704870282
# lead_displacement = [ 177.74337057    9.65670511]
# fish_displacement = [ 175.69282353   10.12807538]
# -----------------------------------
# N=2,leaderRange=54,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 36.23042943]
# tot_avgdist      = 36.23042942988005
# leadRatio        = 0.4195
# leadingTime      = [-1.]
# avg_displacement = 71.68196673807924
# lead_displacement = [ 74.34165075 -50.65462719]
# fish_displacement = [ 69.02228273 -47.14437395]
# -----------------------------------
# N=2,leaderRange=54,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 37.65234212]
# tot_avgdist      = 37.652342118285
# leadRatio        = 0.5981
# leadingTime      = [ 307.9]
# avg_displacement = 230.28792364579292
# lead_displacement = [ 232.79319048   29.70813955]
# fish_displacement = [ 227.78265682   28.46354214]
# -----------------------------------
# N=2,leaderRange=54,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 35.80131121]
# tot_avgdist      = 35.801311207927625
# leadRatio        = 0.5499
# leadingTime      = [ 313.25]
# avg_displacement = 221.95762224087963
# lead_displacement = [ 221.84879371    5.31544409]
# fish_displacement = [ 222.06645077    2.22648668]
# -----------------------------------
# N=2,leaderRange=54,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 22.26280859]
# tot_avgdist      = 22.262808593043847
# leadRatio        = 0.4717
# leadingTime      = [-1.]
# avg_displacement = 134.17016858504724
# lead_displacement = [ 136.34059413  -22.47793654]
# fish_displacement = [ 131.99974304  -23.56712098]
# -----------------------------------
# N=2,leaderRange=54,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 33.53627817]
# tot_avgdist      = 33.53627816772121
# leadRatio        = 0.5824
# leadingTime      = [ 320.]
# avg_displacement = 268.19719863801106
# lead_displacement = [ 269.0835049    22.61244584]
# fish_displacement = [ 267.31089237   20.89854505]
# -----------------------------------
# N=2,leaderRange=54,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 40.40213921]
# tot_avgdist      = 40.40213921264915
# leadRatio        = 0.4601
# leadingTime      = [-1.]
# avg_displacement = 107.26685508180834
# lead_displacement = [ 135.28922     -49.50515705]
# fish_displacement = [ 79.24449016 -52.34492329]
# -----------------------------------
# N=2,leaderRange=54,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 31.50112488]
# tot_avgdist      = 31.501124884336736
# leadRatio        = 0.7598
# leadingTime      = [ 205.15]
# avg_displacement = 311.7397842687725
# lead_displacement = [ 316.57432809  -23.5740769 ]
# fish_displacement = [ 306.90524044  -27.98826852]
# -----------------------------------
# N=2,leaderRange=54,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 26.53173209]
# tot_avgdist      = 26.531732094824463
# leadRatio        = 0.629
# leadingTime      = [ 431.2]
# avg_displacement = 255.6303064323103
# lead_displacement = [ 270.41708924   25.39199934]
# fish_displacement = [ 240.84352362   18.34320657]
# -----------------------------------
# N=2,leaderRange=54,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 23.58325374]
# tot_avgdist      = 23.58325373811496
# leadRatio        = 0.4362
# leadingTime      = [-1.]
# avg_displacement = 88.2641962045751
# lead_displacement = [ 103.97323769  -48.80507194]
# fish_displacement = [ 72.55515472 -57.21358768]
# -----------------------------------
# N=2,leaderRange=54,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 35.5613369]
# tot_avgdist      = 35.56133690415256
# leadRatio        = 0.6145
# leadingTime      = [ 274.]
# avg_displacement = 271.1680396258858
# lead_displacement = [ 272.13852687    7.75125319]
# fish_displacement = [ 270.19755238    6.71668238]
# -----------------------------------
# N=2,leaderRange=54,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 21.33880048]
# tot_avgdist      = 21.338800483860805
# leadRatio        = 0.4327
# leadingTime      = [-1.]
# avg_displacement = 139.85172448109864
# lead_displacement = [ 156.78075758  -17.66050231]
# fish_displacement = [ 122.92269139  -24.07276169]
# -----------------------------------
# N=2,leaderRange=54,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 36.56100015]
# tot_avgdist      = 36.5610001462753
# leadRatio        = 0.6258
# leadingTime      = [ 268.85]
# avg_displacement = 232.0634453658
# lead_displacement = [ 233.30767943   27.4916204 ]
# fish_displacement = [ 230.8192113    23.73927643]
# -----------------------------------
# N=2,leaderRange=54,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 23.458782]
# tot_avgdist      = 23.458782000167155
# leadRatio        = 0.3411
# leadingTime      = [-1.]
# avg_displacement = 24.270671820904347
# lead_displacement = [ 24.93512813 -48.65237201]
# fish_displacement = [ 23.60621551 -45.29349084]
# -----------------------------------
# N=2,leaderRange=54,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 33.00694693]
# tot_avgdist      = 33.00694692682488
# leadRatio        = 0.5789
# leadingTime      = [ 342.]
# avg_displacement = 236.15761194384868
# lead_displacement = [ 238.31870776    6.58913906]
# fish_displacement = [ 233.99651613    5.45877145]
# -----------------------------------
# N=2,leaderRange=54,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 30.5997724]
# tot_avgdist      = 30.599772401997395
# leadRatio        = 0.4806
# leadingTime      = [-1.]
# avg_displacement = 115.92572501715551
# lead_displacement = [ 134.02887966   -5.29387504]
# fish_displacement = [ 97.82257038 -14.60140016]
# -----------------------------------
# N=2,leaderRange=54,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 23.16998064]
# tot_avgdist      = 23.169980643178977
# leadRatio        = 0.5957
# leadingTime      = [ 423.4]
# avg_displacement = 261.7215638736379
# lead_displacement = [ 276.63973186   -8.29736561]
# fish_displacement = [ 246.80339588  -14.67620955]
# -----------------------------------
# N=2,leaderRange=54,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 29.10268059]
# tot_avgdist      = 29.102680587266864
# leadRatio        = 0.5235
# leadingTime      = [ 479.45]
# avg_displacement = 210.98600832497453
# lead_displacement = [ 221.64955886   47.8637952 ]
# fish_displacement = [ 200.32245779   50.04142481]
# -----------------------------------
# N=2,leaderRange=54,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 33.90518329]
# tot_avgdist      = 33.90518328517824
# leadRatio        = 0.5727
# leadingTime      = [ 306.85]
# avg_displacement = 281.5982298387995
# lead_displacement = [ 298.09440624   23.36082171]
# fish_displacement = [ 265.10205343   18.47276904]
# -----------------------------------
# N=2,leaderRange=54,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 17.97207592]
# tot_avgdist      = 17.972075917651406
# leadRatio        = 0.3962
# leadingTime      = [-1.]
# avg_displacement = 54.477146807964886
# lead_displacement = [ 64.65985942 -14.85747121]
# fish_displacement = [ 44.2944342  -14.00116753]
# -----------------------------------
# N=2,leaderRange=54,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 33.48485615]
# tot_avgdist      = 33.48485614696199
# leadRatio        = 0.6453
# leadingTime      = [ 267.75]
# avg_displacement = 286.7134443764901
# lead_displacement = [ 301.73196659  -31.15393739]
# fish_displacement = [ 271.69492217  -37.82152818]
# -----------------------------------
# N=2,leaderRange=60,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 32.35681615]
# tot_avgdist      = 32.35681614505944
# leadRatio        = 0.5392
# leadingTime      = [-1.]
# avg_displacement = 147.06134345017034
# lead_displacement = [ 158.20858663   54.27428338]
# fish_displacement = [ 135.91410027   55.08863634]
# -----------------------------------
# N=2,leaderRange=60,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 47.92885415]
# tot_avgdist      = 47.928854148971006
# leadRatio        = 0.7196
# leadingTime      = [ 337.55]
# avg_displacement = 265.4030072577272
# lead_displacement = [ 296.98172823  -47.10034698]
# fish_displacement = [ 233.82428629  -50.93540614]
# -----------------------------------
# N=2,leaderRange=60,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 34.47217022]
# tot_avgdist      = 34.47217021509073
# leadRatio        = 0.5918
# leadingTime      = [ 323.4]
# avg_displacement = 243.92573673401853
# lead_displacement = [ 255.52613426  -73.34913291]
# fish_displacement = [ 232.32533921  -75.71788597]
# -----------------------------------
# N=2,leaderRange=60,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 33.23080139]
# tot_avgdist      = 33.23080139222142
# leadRatio        = 0.6685
# leadingTime      = [ 364.55]
# avg_displacement = 249.17120802145902
# lead_displacement = [ 281.491057      7.12271642]
# fish_displacement = [ 216.85135904    2.32044866]
# -----------------------------------
# N=2,leaderRange=60,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 28.9667862]
# tot_avgdist      = 28.966786199334297
# leadRatio        = 0.4747
# leadingTime      = [ 450.85]
# avg_displacement = 179.1260039188855
# lead_displacement = [ 183.43433005  -14.97056995]
# fish_displacement = [ 174.81767779  -14.78707131]
# -----------------------------------
# N=2,leaderRange=60,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 50.2626837]
# tot_avgdist      = 50.262683695471665
# leadRatio        = 0.6968
# leadingTime      = [ 328.5]
# avg_displacement = 278.9260525317487
# lead_displacement = [ 309.77885394   13.74415478]
# fish_displacement = [ 248.07325113    9.64802293]
# -----------------------------------
# N=2,leaderRange=60,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 36.65440055]
# tot_avgdist      = 36.654400545774415
# leadRatio        = 0.4631
# leadingTime      = [-1.]
# avg_displacement = 158.96312572617794
# lead_displacement = [ 172.01426825   15.95559185]
# fish_displacement = [ 145.9119832    11.36632264]
# -----------------------------------
# N=2,leaderRange=60,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 20.81004175]
# tot_avgdist      = 20.81004174566279
# leadRatio        = 0.6071
# leadingTime      = [ 401.75]
# avg_displacement = 283.6702500264439
# lead_displacement = [ 299.05173774    1.44403248]
# fish_displacement = [ 268.28876231   -4.5152153 ]
# -----------------------------------
# N=2,leaderRange=60,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 23.83687637]
# tot_avgdist      = 23.836876367876737
# leadRatio        = 0.4387
# leadingTime      = [-1.]
# avg_displacement = 86.82853322599595
# lead_displacement = [ 90.21421423 -73.11227934]
# fish_displacement = [ 83.44285223 -75.42902448]
# -----------------------------------
# N=2,leaderRange=60,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 44.61531966]
# tot_avgdist      = 44.61531965662952
# leadRatio        = 0.511
# leadingTime      = [ 467.8]
# avg_displacement = 217.22293637005117
# lead_displacement = [ 232.03455532  -69.56148542]
# fish_displacement = [ 202.41131742  -75.04598272]
# -----------------------------------
# N=2,leaderRange=60,run=0
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 23.60704638]
# tot_avgdist      = 23.607046384359524
# leadRatio        = 0.3733
# leadingTime      = [-1.]
# avg_displacement = 8.736304904041443
# lead_displacement = [ 27.11922024 -28.06223719]
# fish_displacement = [ -9.64661043 -37.02720129]
# -----------------------------------
# N=2,leaderRange=60,run=1
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 48.52140459]
# tot_avgdist      = 48.52140458662144
# leadRatio        = 0.6973
# leadingTime      = [ 337.45]
# avg_displacement = 271.4714211820437
# lead_displacement = [ 303.06930138    6.29597643]
# fish_displacement = [ 239.87354099    1.62105617]
# -----------------------------------
# N=2,leaderRange=60,run=2
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 35.04499036]
# tot_avgdist      = 35.044990356123265
# leadRatio        = 0.5434
# leadingTime      = [ 447.85]
# avg_displacement = 240.32043562461877
# lead_displacement = [ 253.38317797   28.77285933]
# fish_displacement = [ 227.25769328   24.38559352]
# -----------------------------------
# N=2,leaderRange=60,run=3
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 44.15960976]
# tot_avgdist      = 44.1596097596923
# leadRatio        = 0.6562
# leadingTime      = [ 375.15]
# avg_displacement = 227.16721156970945
# lead_displacement = [ 257.7786354   -25.00711907]
# fish_displacement = [ 196.55578774  -30.21306414]
# -----------------------------------
# N=2,leaderRange=60,run=4
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 28.40335653]
# tot_avgdist      = 28.403356531145523
# leadRatio        = 0.3501
# leadingTime      = [-1.]
# avg_displacement = 46.24170498896241
# lead_displacement = [ 49.58637372  29.05258266]
# fish_displacement = [ 42.89703625  29.2407445 ]
# -----------------------------------
# N=2,leaderRange=60,run=5
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 22.27187513]
# tot_avgdist      = 22.27187513349052
# leadRatio        = 0.5262
# leadingTime      = [ 436.65]
# avg_displacement = 249.40093197704456
# lead_displacement = [ 263.44460408  -73.76152743]
# fish_displacement = [ 235.35725988  -79.32584229]
# -----------------------------------
# N=2,leaderRange=60,run=6
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 36.84450963]
# tot_avgdist      = 36.844509634927306
# leadRatio        = 0.5239
# leadingTime      = [ 204.]
# avg_displacement = 200.76924482437525
# lead_displacement = [ 203.12055097   26.2628061 ]
# fish_displacement = [ 198.41793868   30.12595332]
# -----------------------------------
# N=2,leaderRange=60,run=7
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 23.63611961]
# tot_avgdist      = 23.636119611432736
# leadRatio        = 0.5342
# leadingTime      = [ 308.1]
# avg_displacement = 231.44201862917737
# lead_displacement = [ 232.76397922    0.6300066 ]
# fish_displacement = [ 230.12005804   -1.93210323]
# -----------------------------------
# N=2,leaderRange=60,run=8
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 20.507441]
# tot_avgdist      = 20.507440998795808
# leadRatio        = 0.4117
# leadingTime      = [-1.]
# avg_displacement = 65.75460811405162
# lead_displacement = [ 78.58222445   1.77494167]
# fish_displacement = [ 52.92699178   2.08962808]
# -----------------------------------
# N=2,leaderRange=60,run=9
# -----------------------------------
# Leader i=0
# -----------
# all_avgdist      = [ 30.62907427]
# tot_avgdist      = 30.629074271800654
# leadRatio        = 0.5317
# leadingTime      = [ 450.35]
# avg_displacement = 237.48531061141688
# lead_displacement = [ 251.372718  -31.533358]
# fish_displacement = [ 223.59790322  -38.44566541]
# -----------------------------------

# %%
slc.ProcessParallelResults(para1name,para2name,para_list,outdata_list,
                           outpath="/home/prom/work/tmp/results.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-32b166089737> in <module>
# ----> 1 slc.ProcessParallelResults(para1name,para2name,para_list,outdata_list,
#       2                            outpath="/home/prom/work/tmp/results.h5")
#
# NameError: name 'para1name' is not defined

# %%
a=10.
array=np.array(a,ndmin=1)
print(type(a))
print(array)
# Out:
# <class 'float'>
# [10.]

# %%
dataDict=dict()
dataDict['a']=[2]
dataDict['b']=[3]
df=pd.DataFrame.from_dict(dataDict,)
df
# Out:
#    a  b
# 0  2  3

# %%
dataDict=dict()
dataDict['test']=34
dataArray=np.arange(10)
dataKey='number'
dataDict=slc.CreateDictEntriesForArrayData(dataDict,dataKey,dataArray)

# %%
a='test'
if(a=='blabla'):
    print("yes")

# %%
infile='/home/prom/work/Leadership/DATA/Leader-NaiveLeader/para_targetType2_leadershipRangeList_6.0_36.0_leader_algstrength_1.0_3.0.pkl'
para=pkl.load(open(infile,'rb'))
para['targetVectorList']
# Out:
# [[2000, 0]]

# %%
infile='/home/prom/work/Leadership/DATA/Leader-NaiveLeader/para_targetType2_leadershipRangeList_6.0_36.0_leader_algstrength_0.5_3.0.pkl'
para1=pkl.load(open(infile,'rb'))
infile='/home/prom/work/Leadership/DATA/para_targetType2_leadershipRange_0.0_72.0_leader_algstrength_0.5_3.0.pkl'
para2=pkl.load(open(infile,'rb'))

# %%
for k in para.keys():
    print(k,para1[k])
    #print(k,para1[k],para2[k])
# Out:
# time 300.0
# dt 0.05
# output 0.5
# L 3000
# N 2
# IC 0
# BC 0
# int_type matrix
# dist_dependence overlap
# steps 6000
# stepout 10
# outsteps 600
# alpha 0.5
# speed0 5.0
# wallrepdist 1
# wallrepstrength 5.0
# attstrengthDist 0
# attstrength 2.0
# attrange 30.0
# attsteepness -20
# repstrength 5.0
# reprange 3.0
# repsteepness -20
# algstrength 0.0
# algrange 5.0
# algsteepness -20
# blindangle 0.0
# blindanglesteepness 50
# kneigh 6
# noisep 2.0
# sigmap 0.4472135954999579
# targetType 2
# leaderCount 2
# leadershipWeight 0.0
# leadershipRangeList []
# leadershipRange 12
# recruitingRangeList []
# recruitingRange 6
# recruitingTime 0.05
# recruitingAttStrength 5.0
# recruitingStrategy nearest
# recruitingSpeed 6.0
# leadingDistance 2000
# targetVectorList [[2000, 0]]
# targetVector [2000, 0]
# deltaDistTarget 5
# leader_repstrength 5.0
# leader_algstrength 4.0
# leader_attstrength 4.0
# leader_reprange 3.0
# leader_algrange 0.5
# leader_attrange 1000.0
# leader_desiredPhi [0.0, None]
# leader_noisep 1.0
# leader_sigmap 0.31622776601683794

# %%
infile="/mnt/DATA/leadershipModelOLD/leadershipRange_0_72_noisep_2.0_4.0.h5"
infile="/mnt/DATA/leadershipModelOLD/recruitingStrength5/attstrengthDist0_v5/leadershipRange_0_72_noisep_1.0_2.5.h5"
infile="/mnt/DATA/leadershipModelOLD/recruitingStrength5/attstrengthDist1_v5/leadershipRange_0_72_noisep_1.0_2.5.h5"
infile="/mnt/DATA/leadershipModelOLD/recruitingStrength20/attstrengthDist1_v8/leadershipRange_0_72_noisep_2.0_4.0.h5"
infile="/mnt/DATA/leadershipModel/speed5/leadershipRange_0_72_noisep_2.0_5.0.h5"
infile="/mnt/DATA/leadershipModel/targetType0_leadershipRange_0_72_noisep_2.0_5.0.h5"
infile="/home/prom/work/Leadership/DATA/Leader-NaiveLeader/targetType2_leadershipRangeList_6.0_36.0_leader_algstrength_1.0_3.0.h5"
infile="/home/prom/work/Leadership/DATA/targetType2_leadershipRange_0.0_72.0_leader_algstrength_0.5_3.0.h5"
df=pd.read_hdf(infile)
filename=infile.split("/")[-1][:-3]
srcpath=infile[:-(len(filename)+3)]
print(srcpath,filename)
#filenameWithoutNoiseList=filename.split('_')[:-2]
#filenameWithoutNoise=""
#for fstr in filenameWithoutNoiseList:
#    filenameWithoutNoise+=fstr+'_'
#print(filenameWithoutNoise)
#df.to_csv(srcpath+filename+'.csv',index=False)
#df0=pd.read_hdf("/mnt/DATA/leadershipModel/leadershipRange_0_0_noisep_1.0_2.5.h5")
#df.iloc[:300]=df0.iloc[:300]
#df.to_csv("/mnt/DATA/leadershipModel/leadershipRange_0_72_noisep_1.0_2.5.csv",index=False)
#print(pd.unique(df.noisep))

val=1.0
var='leader_algstrength0'
if(len(pd.unique(df[var]))>1):
    df_tmp=df[df[var]==val]
else:
    df_tmp=df
    
groupVar='leadershipRange0'
dfgrouped=df_tmp.groupby([groupVar],as_index=False).mean()

df_tmp
# Out:
# /home/prom/work/Leadership/DATA/ targetType2_leadershipRange_0.0_72.0_leader_algstrength_0.5_3.0
#       leadershipRange0  leader_algstrength0  run  leadRatio0  tot_avgdist0  \
# 100                0.0                  1.0    0    0.000000      4.251403
# 101                0.0                  1.0    1    0.000000      4.289085
# 102                0.0                  1.0    2    0.000000      4.124782
# 103                0.0                  1.0    3    0.000000      3.923935
# 104                0.0                  1.0    4    0.000000      4.174590
# ...                ...                  ...  ...         ...           ...
# 2595              72.0                  1.0   95    0.878434     20.508945
# 2596              72.0                  1.0   96    1.000000     13.924876
# 2597              72.0                  1.0   97    1.000000      8.481785
# 2598              72.0                  1.0   98    1.000000     16.175060
# 2599              72.0                  1.0   99    1.000000      9.911184
#
#       tot_finaldist0  avg_displacement0  finalDistToTarget0  \
# 100         4.788545          58.016886           76.835474
# 101         3.469610          73.759694            5.700457
# 102         6.056819          17.928264           86.008261
# 103         3.845736          75.531069            5.024968
# 104         4.860214          75.292364            4.695022
# ...              ...                ...                 ...
# 2595        9.433426          74.139084            4.816930
# 2596       15.465366          71.809316            5.657312
# 2597       11.325412          69.313967            5.164967
# 2598       18.807281          63.651400            6.084670
# 2599       12.142483          70.132212            5.500787
#
#       finalDistToTarget1  targetMovement00  targetMovement01  tot_time  \
# 100            81.619191          0.041836          0.034786    300.00
# 101             6.919533          0.071113          0.067773     25.25
# 102            85.926934          0.015817          0.015172    300.00
# 103             5.158853          0.068570          0.073622     33.60
# 104             6.215694          0.071155          0.070665    108.50
# ...                  ...               ...               ...       ...
# 2595            8.918401          0.069454          0.070241     85.55
# 2596           12.667469          0.071880          0.063291     25.80
# 2597           16.460689          0.066723          0.063932     21.60
# 2598           24.835194          0.070077          0.050357     22.80
# 2599           14.392850          0.070123          0.062062     24.70
#
#       leadingTime0
# 100          -1.00
# 101          25.25
# 102          -1.00
# 103          33.60
# 104         108.50
# ...            ...
# 2595         85.55
# 2596         25.80
# 2597         21.60
# 2598         22.80
# 2599         24.70
#
# [700 rows x 13 columns]

# %%
xvar='leadershipRange0'
yvar='targetMovement01'
yvar='leadRatio0'

#print(np.shape(leadershipRanges))
#leadershipRangesA=np.array(leadershipRanges)
x=df[xvar]
y=np.array(df[yvar])
xm=np.array(dfgrouped[xvar])
ym=np.array(dfgrouped[yvar])
#y[y>2500]=3000-y[y>2500]
figure()
#df.leadershipRangeList.iloc[:][0]
plot(x,y,'o')
plot(xm,ym,'ro')
xlabel(xvar)
ylabel(yvar)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# Text(0, 0.5, 'leadRatio0')

# %%
dfgrouped
# Out:
#    leadershipRange0  leadershipRange1  leader_algstrength0   run  leadRatio0  \
# 0              12.0              12.0                  3.0  49.5    0.922763
# 1              24.0              12.0                  3.0  49.5    0.978758
# 2              36.0              12.0                  3.0  49.5    0.995790
#
#    leadRatio1  tot_avgdist0  tot_avgdist1  tot_finaldist0  tot_finaldist1  \
# 0    0.922763      5.879999      5.879999        5.588470        5.588470
# 1    0.734135      7.841532      7.841532        7.313367        7.313367
# 2    0.724095      7.788155      7.788155        7.120580        7.120580
#
#    avg_displacement0  finalDistToTarget0  finalDistToTarget1  \
# 0        1404.428767          590.431509          592.344692
# 1        1418.981355          573.259891          579.196704
# 2        1458.749438          533.505591          539.349899
#
#    targetMovement00  targetMovement01  tot_time  leadingTime
# 0          0.936955          0.935456     300.0         -1.0
# 1          0.948050          0.943776     300.0         -1.0
# 2          0.974346          0.970785     300.0         -1.0

# %%
leadTime
# Out:
# 1100   -1.0
# 1101   -1.0
# 1102   -1.0
# 1103   -1.0
# 1104   -1.0
#        ...
# 4795   -1.0
# 4796   -1.0
# 4797   -1.0
# 4798   -1.0
# 4799   -1.0
# Name: leadingTime, Length: 300, dtype: float64

# %%
############### Select data #####################
var=3.0
df_tmp=df[df.leader_algstrength0==var]
df_tmp=df_tmp[df_tmp.leadershipRange0.isin([0,12,24,36,48,60,72])]
#df_tmp.to_csv(srcpath+filenameWithoutNoise+'{}_asInExp.csv'.format(noise))
dfgrouped=df_tmp.groupby(['leadershipRange0'],as_index=False).mean()
dfgrouped_std=df_tmp.groupby(['leadershipRange0'],as_index=False).std()

print(dfgrouped)

xt=[0,12,24,36,48,60,72]

try:
    leadTime=df_tmp.leadingTime0
except:
    leadTime=df_tmp.leadingTime


################ Create Figures ###########################
figure(figsize=(12,6))
subplot(231)
semilogy(df_tmp.leadershipRange0,df_tmp.leadingTime0,'.')
plot(dfgrouped.leadershipRange0, dfgrouped.leadingTime0,'ro')
xlabel('LeadZ Radius')
ylabel('Time to goal')
ylim([1,1000])
xticks(xt)
tight_layout()
#savefig(srcpath+"LeadingTime_vs_LeadZ_noise{}.png".format(noise),dpi=300)

subplot(232)
#figure(figsize=(4,3))
plot(df_tmp.leadershipRange0,df_tmp.tot_avgdist0,'.')
plot(dfgrouped.leadershipRange0,dfgrouped.tot_avgdist0,'ro')
xlabel('LeadZ radius')
ylabel('Distance to Leader')
xticks(xt)
tight_layout()
#savefig(srcpath+"DistLeader_vs_LeadZ_noise{}.png".format(noise),dpi=300)

subplot(233)
#figure(figsize=(4,3))
plot(df_tmp.leadershipRange0,df_tmp.leadRatio0,'.')
plot(dfgrouped.leadershipRange0,dfgrouped.leadRatio0,'ro')
xlabel('LeadZ radius')
ylabel('Leading mode ratio')
tight_layout()
xticks(xt)
#savefig(srcpath+"LeadRatio_vs_LeadZ_noise{}.png".format(noise),dpi=300)
#savefig(srcpath+"LeadPerformence_vs_LeadZ_var{}.png".format(var),dpi=300)

subplot(234)
errorbar(dfgrouped.leadershipRange0,np.zeros(len(dfgrouped.leadershipRange0)),yerr=dfgrouped_std.leadingTime0,capsize=5)
xlabel('LeadZ Radius')
ylabel('Std. time to goal')
ylim([-200,200])
xticks(xt)
tight_layout()

subplot(235)
errorbar(dfgrouped.leadershipRange0,np.zeros(len(dfgrouped.leadershipRange0)),yerr=dfgrouped_std.tot_avgdist0,capsize=5)
xlabel('LeadZ Radius')
ylabel('Std. distance to leader')
ylim([-10,+10])
xticks(xt)
tight_layout()

subplot(236)
errorbar(dfgrouped.leadershipRange0,np.zeros(len(dfgrouped.leadershipRange0)),yerr=dfgrouped_std.leadRatio0,capsize=5)
xlabel('LeadZ Radius')
ylabel('Std. lead mode ratio')
ylim([-0.3,+0.3])
xticks(xt)
tight_layout()
#savefig(srcpath+"LeadingResults_var{}_AsInExp.png".format(var))

#outdata_list=data[0]
#para_list=data[1]
# Out:
#    leadershipRange0  leader_algstrength0   run  leadRatio0  tot_avgdist0  \
# 0               0.0                  3.0  49.5    0.000000      5.423961
# 1              12.0                  3.0  49.5    0.691084      9.374197
# 2              24.0                  3.0  49.5    0.860326     12.200611
# 3              36.0                  3.0  49.5    0.896934     14.356395
# 4              48.0                  3.0  49.5    0.905911     15.440732
# 5              60.0                  3.0  49.5    0.966346     14.163537
# 6              72.0                  3.0  49.5    0.987589     16.644004
#
#    tot_finaldist0  avg_displacement0  finalDistToTarget0  finalDistToTarget1  \
# 0        5.312738          70.744947           11.364157           11.028308
# 1        7.482965          71.101678            5.692506           10.579329
# 2       11.942748          67.751248            5.788687           16.920234
# 3       13.873126          67.193580            5.801566           18.872089
# 4       14.613465          67.161169            5.733591           19.308993
# 5       16.493259          66.616127            5.668981           21.490213
# 6       23.107038          65.483497            5.830961           28.135469
#
#    targetMovement00  targetMovement01  tot_time  leadingTime0
# 0          0.066048          0.066544  126.9725       93.8625
# 1          0.067661          0.066345   43.8205       43.8205
# 2          0.067446          0.060248   30.4365       30.4365
# 3          0.067066          0.059493   31.4235       31.4235
# 4          0.067054          0.059319   33.5745       33.5745
# 5          0.067476          0.057755   26.1060       26.1060
# 6          0.066932          0.054834   22.7130       22.7130
# <img src="data:image/png;base64,..." width="1199.9166666666667">

# %%
print(srcpath)sIn
# Out:
# /mnt/DATA/leadershipModelOLD/recruitingStrength5/attstrengthDist1_v5/

# %%
############### Select data - targetType 0 #####################
noise=4
df_tmp=df[df.noisep==noise]
df_tmp=df_tmp[df_tmp.leadershipRange.isin([0,12,24,36,48,60,72])]
df_tmp.to_csv(srcpath+filenameWithoutNoise+'{}.csv'.format(noise))
dfgrouped=df_tmp.groupby(['leadershipRange'],as_index=False).mean()
dfgrouped_std=df_tmp.groupby(['leadershipRange'],as_index=False).std()

# %%
dfgrouped
# Out:
#    leadershipRange  noisep   run  leadRatio  tot_avgdist  avg_displacement  \
# 0              0.0     4.0  49.5   0.000000     8.027372         69.524189
# 1             12.0     4.0  49.5   0.340806    15.787685         92.865503
# 2             24.0     4.0  49.5   0.418522    20.566776         96.553949
# 3             36.0     4.0  49.5   0.448606    25.846538         62.883975
# 4             48.0     4.0  49.5   0.513026    30.356270         92.615589
# 5             60.0     4.0  49.5   0.578722    36.513362         93.360433
# 6             72.0     4.0  49.5   0.600932    40.837745        104.488261
#
#     tot_time  leadingTime  lead_displacement  fish_displacement
# 0  2031.5028    1031.4028          67.681637          71.366741
# 1   838.6192     638.5992          94.052553          91.678453
# 2   507.5709     407.5609          99.268255          93.839643
# 3   464.3452     364.3352          64.720321          61.047630
# 4   235.8650     235.8650          96.949423          88.281755
# 5   342.6244     342.6244         103.045871          83.674995
# 6   278.4240     278.4240         112.862572          96.113949

# %%
df_tmp.to_csv('/mnt/DATA/leadershipModel/leadershipRange_0_72_noisep_{}_asInExp.csv'.format(noise))

# %%
#df[(df.leadershipRange==0) & (df.leadingTime>0)]

# %%
#dfgrouped

# %%
figure(figsize=(4,3))
semilogy(df_tmp.leadershipRange,df_tmp.leadingTime,'.')
plot(dfgrouped.leadershipRange,dfgrouped.leadingTime,'ro')
xlabel('LeadZ Radius')
ylabel('Leading Time')
ylim([1,1000])
tight_layout()
savefig(srcpath+"LeadingTime_vs_LeadZ_noise{}.png".format(noise),dpi=300)

figure(figsize=(4,3))
plot(df_tmp.leadershipRange,df_tmp.tot_avgdist,'.')
plot(dfgrouped.leadershipRange,dfgrouped.tot_avgdist,'ro')
xlabel('LeadZ radius')
ylabel('Distance to Leader')
tight_layout()
savefig(srcpath+"DistLeader_vs_LeadZ_noise{}.png".format(noise),dpi=300)


figure(figsize=(4,3))
plot(df_tmp.leadershipRange,df_tmp.leadRatio,'.')
plot(dfgrouped.leadershipRange,dfgrouped.leadRatio,'ro')
xlabel('LeadZ radius')
ylabel('Leading mode ratio')
tight_layout()
savefig(srcpath+"LeadRatio_vs_LeadZ_noise{}.png".format(noise),dpi=300)

# %%
#pd.unique(df_tmp[df_tmp.leadershipRange==2].avg_displacement)

# %%
#df_tmp.leadershipRange

# %%
para_list[i]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7165779cbc17> in <module>()
# ----> 1 para_list[i]
#
# NameError: name 'para_list' is not defined
